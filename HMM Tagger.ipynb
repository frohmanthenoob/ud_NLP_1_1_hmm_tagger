# %% [markdown]
# # Project: Part of Speech Tagging with Hidden Markov Models
# ---
# ### Introduction
#
# Part of speech tagging is the process of determining the syntactic category of a word from the words in its surrounding context. It is often used to help disambiguate natural language phrases because it can be done quickly with high accuracy. Tagging can be used for many NLP tasks like determining correct pronunciation during speech synthesis (for example, _dis_-count as a noun vs dis-_count_ as a verb), for information retrieval, and for word sense disambiguation.
#
# In this notebook, you'll use the [Pomegranate](http://pomegranate.readthedocs.io/) library to build a hidden Markov model for part of speech tagging using a "universal" tagset. Hidden Markov models have been able to achieve [>96% tag accuracy with larger tagsets on realistic text corpora](http://www.coli.uni-saarland.de/~thorsten/publications/Brants-ANLP00.pdf). Hidden Markov models have also been used for speech recognition and speech generation, machine translation, gene recognition for bioinformatics, and human gesture recognition for computer vision, and more.
#
# ![](_post-hmm.png)
#
# The notebook already contains some code to get you started. You only need to add some new functionality in the areas indicated to complete the project; you will not need to modify the included code beyond what is requested. Sections that begin with **'IMPLEMENTATION'** in the header indicate that you must provide code in the block that follows. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You must then **export the notebook** by running the last cell in the notebook, or by using the menu above and navigating to **File -> Download as -> HTML (.html)** Your submissions should include both the `html` and `ipynb` files.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** Code and Markdown cells can be executed using the `Shift + Enter` keyboard shortcut. Markdown cells can be edited by double-clicking the cell to enter edit mode.
# </div>

# %% [markdown]
# ### The Road Ahead
# You must complete Steps 1-3 below to pass the project. The section on Step 4 includes references & resources you can use to further explore HMM taggers.
#
# - [Step 1](#Step-1:-Read-and-preprocess-the-dataset): Review the provided interface to load and access the text corpus
# - [Step 2](#Step-2:-Build-a-Most-Frequent-Class-tagger): Build a Most Frequent Class tagger to use as a baseline
# - [Step 3](#Step-3:-Build-an-HMM-tagger): Build an HMM Part of Speech tagger and compare to the MFC baseline
# - [Step 4](#Step-4:-[Optional]-Improving-model-performance): (Optional) Improve the HMM tagger

# %% [markdown]
# <div class="alert alert-block alert-warning">
# **Note:** Make sure you have selected a **Python 3** kernel in Workspaces or the hmm-tagger conda environment if you are running the Jupyter server on your own machine.
# </div>

# %%
# Jupyter "magic methods" -- only need to be run once per kernel restart
# %load_ext autoreload
# %aimport helpers, tests
# %autoreload 1
# Out:
# /home/frohman/anaconda3/envs/hmm-tagger/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/frohman/anaconda3/envs/hmm-tagger/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# import python modules -- this cell needs to be run again if you make changes to any of the files
import matplotlib.pyplot as plt
import numpy as np

from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict
from helpers import show_model, Dataset
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
# Out:
# /home/frohman/anaconda3/envs/hmm-tagger/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ## Step 1: Read and preprocess the dataset
# ---
# We'll start by reading in a text corpus and splitting it into a training and testing dataset. The data set is a copy of the [Brown corpus](https://en.wikipedia.org/wiki/Brown_Corpus) (originally from the [NLTK](https://www.nltk.org/) library) that has already been pre-processed to only include the [universal tagset](https://arxiv.org/pdf/1104.2086.pdf). You should expect to get slightly higher accuracy using this simplified tagset than the same model would achieve on a larger tagset like the full [Penn treebank tagset](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html), but the process you'll follow would be the same.
#
# The `Dataset` class provided in helpers.py will read and parse the corpus. You can generate your own datasets compatible with the reader by writing them to the following format. The dataset is stored in plaintext as a collection of words and corresponding tags. Each sentence starts with a unique identifier on the first line, followed by one tab-separated word/tag pair on each following line. Sentences are separated by a single blank line.
#
# Example from the Brown corpus.
# ```
# b100-38532
# Perhaps	ADV
# it	PRON
# was	VERB
# right	ADJ
# ;	.
# ;	.
#
# b100-35577
# ...
# ```

# %%
data = Dataset("tags-universal.txt", "brown-universal.txt", train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 57340 sentences in the corpus.
# There are 45872 sentences in the training set.
# There are 11468 sentences in the testing set.

# %% [markdown]
# ### The Dataset Interface
#
# You can access (mostly) immutable references to the dataset through a simple interface provided through the `Dataset` class, which represents an iterable collection of sentences along with easy access to partitions of the data for training & testing. Review the reference below, then run and review the next few cells to make sure you understand the interface before moving on to the next step.
#
# ```
# Dataset-only Attributes:
#     training_set - reference to a Subset object containing the samples for training
#     testing_set - reference to a Subset object containing the samples for testing
#
# Dataset & Subset Attributes:
#     sentences - a dictionary with an entry {sentence_key: Sentence()} for each sentence in the corpus
#     keys - an immutable ordered (not sorted) collection of the sentence_keys for the corpus
#     vocab - an immutable collection of the unique words in the corpus
#     tagset - an immutable collection of the unique tags in the corpus
#     X - returns an array of words grouped by sentences ((w11, w12, w13, ...), (w21, w22, w23, ...), ...)
#     Y - returns an array of tags grouped by sentences ((t11, t12, t13, ...), (t21, t22, t23, ...), ...)
#     N - returns the number of distinct samples (individual words or tags) in the dataset
#
# Methods:
#     stream() - returns an flat iterable over all (word, tag) pairs across all sentences in the corpus
#     __iter__() - returns an iterable over the data as (sentence_key, Sentence()) pairs
#     __len__() - returns the nubmer of sentences in the dataset
# ```
#
# For example, consider a Subset, `subset`, of the sentences `{"s0": Sentence(("See", "Spot", "run"), ("VERB", "NOUN", "VERB")), "s1": Sentence(("Spot", "ran"), ("NOUN", "VERB"))}`. The subset will have these attributes:
#
# ```
# subset.keys == {"s1", "s0"}  # unordered
# subset.vocab == {"See", "run", "ran", "Spot"}  # unordered
# subset.tagset == {"VERB", "NOUN"}  # unordered
# subset.X == (("Spot", "ran"), ("See", "Spot", "run"))  # order matches .keys
# subset.Y == (("NOUN", "VERB"), ("VERB", "NOUN", "VERB"))  # order matches .keys
# subset.N == 7  # there are a total of seven observations over all sentences
# len(subset) == 2  # because there are two sentences
# ```
#
# <div class="alert alert-block alert-info">
# **Note:** The `Dataset` class is _convenient_, but it is **not** efficient. It is not suitable for huge datasets because it stores multiple redundant copies of the same data.
# </div>

# %% [markdown]
# #### Sentences
#
# `Dataset.sentences` is a dictionary of all sentences in the training corpus, each keyed to a unique sentence identifier. Each `Sentence` is itself an object with two attributes: a tuple of the words in the sentence named `words` and a tuple of the tag corresponding to each word named `tags`.

# %%
key = 'b100-38532'
print("Sentence: {}".format(key))
print("words:\n\t{!s}".format(data.sentences[key].words))
print("tags:\n\t{!s}".format(data.sentences[key].tags))
# Out:
# Sentence: b100-38532
# words:
# 	('Perhaps', 'it', 'was', 'right', ';', ';')
# tags:
# 	('ADV', 'PRON', 'VERB', 'ADJ', '.', '.')

# %% [markdown]
# <div class="alert alert-block alert-info">
# **Note:** The underlying iterable sequence is **unordered** over the sentences in the corpus; it is not guaranteed to return the sentences in a consistent order between calls. Use `Dataset.stream()`, `Dataset.keys`, `Dataset.X`, or `Dataset.Y` attributes if you need ordered access to the data.
# </div>
#
# #### Counting Unique Elements
#
# You can access the list of unique words (the dataset vocabulary) via `Dataset.vocab` and the unique list of tags via `Dataset.tagset`.

# %%
print("There are a total of {} samples of {} unique words in the corpus."
      .format(data.N, len(data.vocab)))
print("There are {} samples of {} unique words in the training set."
      .format(data.training_set.N, len(data.training_set.vocab)))
print("There are {} samples of {} unique words in the testing set."
      .format(data.testing_set.N, len(data.testing_set.vocab)))
print("There are {} words in the test set that are missing in the training set."
      .format(len(data.testing_set.vocab - data.training_set.vocab)))

assert data.N == data.training_set.N + data.testing_set.N, \
       "The number of training + test samples should sum to the total number of samples"
# Out:
# There are a total of 1161192 samples of 56057 unique words in the corpus.
# There are 928458 samples of 50536 unique words in the training set.
# There are 232734 samples of 25112 unique words in the testing set.
# There are 5521 words in the test set that are missing in the training set.

# %% [markdown]
# #### Accessing word and tag Sequences
# The `Dataset.X` and `Dataset.Y` attributes provide access to ordered collections of matching word and tag sequences for each sentence in the dataset.

# %%
# accessing words with Dataset.X and tags with Dataset.Y 
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('Mr.', 'Podger', 'had', 'thanked', 'him', 'gravely', ',', 'and', 'now', 'he', 'made', 'use', 'of', 'the', 'advice', '.')
#
# Labels 1: ('NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'ADV', '.', 'CONJ', 'ADV', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', '.')
#
# Sentence 2: ('But', 'there', 'seemed', 'to', 'be', 'some', 'difference', 'of', 'opinion', 'as', 'to', 'how', 'far', 'the', 'board', 'should', 'go', ',', 'and', 'whose', 'advice', 'it', 'should', 'follow', '.')
#
# Labels 2: ('CONJ', 'PRT', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'ADP', 'ADV', 'ADV', 'DET', 'NOUN', 'VERB', 'VERB', '.', 'CONJ', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', '.')

# %% [markdown]
# #### Accessing (word, tag) Samples
# The `Dataset.stream()` method returns an iterator that chains together every pair of (word, tag) entries across all sentences in the entire corpus.

# %%
# use Dataset.stream() (word, tag) samples for the entire corpus
print("\nStream (word, tag) pairs:\n")
for i, pair in enumerate(data.stream()):
    print("\t", pair)
    if i > 5: break
# Out:
# Stream (word, tag) pairs:
#
# 	 ('Mr.', 'NOUN')
# 	 ('Podger', 'NOUN')
# 	 ('had', 'VERB')
# 	 ('thanked', 'VERB')
# 	 ('him', 'PRON')
# 	 ('gravely', 'ADV')
# 	 (',', '.')

# %% [markdown]
# For both our baseline tagger and the HMM model we'll build, we need to estimate the frequency of tags & words from the frequency counts of observations in the training corpus. In the next several cells you will complete functions to compute the counts of several sets of counts.

# %% [markdown]
# ## Step 2: Build a Most Frequent Class tagger
# ---
#
# Perhaps the simplest tagger (and a good baseline for tagger performance) is to simply choose the tag most frequently assigned to each word. This "most frequent class" tagger inspects each observed word in the sequence and assigns it the label that was most often assigned to that word in the corpus.

# %% [markdown]
# ### IMPLEMENTATION: Pair Counts
#
# Complete the function below that computes the joint frequency counts for two input sequences.

# %%
def pair_counts(sequences_A, sequences_B):
    """Return a dictionary keyed to each unique value in the first sequence list
    that counts the number of occurrences of the corresponding value from the
    second sequences list.
    
    For example, if sequences_A is tags and sequences_B is the corresponding
    words, then if 1244 sequences contain the word "time" tagged as a NOUN, then
    you should return a dictionary such that pair_counts[NOUN][time] == 1244
    """
    a = {}
    for ttuple,wtuple in zip(sequences_A,sequences_B):
        for t,w in zip(ttuple,wtuple):
            if t in a.keys():
                if w in a[t].keys():
                    a[t][w] = a[t][w]+1
                else:
                    a[t].update({w:1})
            else:
                a[t] = {w:1}
    return a

# Calculate C(t_i, w_i)
emission_counts = pair_counts(data.Y,data.X)

assert len(emission_counts) == 12, \
       "Uh oh. There should be 12 tags in your dictionary."
assert max(emission_counts["NOUN"], key=emission_counts["NOUN"].get) == 'time', \
       "Hmmm...'time' is expected to be the most common NOUN."
HTML('<div class="alert alert-block alert-success">Your emission counts look good!</div>')
# Out:
# <div class="alert alert-block alert-success">Your emission counts look good!</div>

# %% [markdown]
# ### IMPLEMENTATION: Most Frequent Class Tagger
#
# Use the `pair_counts()` function and the training dataset to find the most frequent class label for each word in the training data, and populate the `mfc_table` below. The table keys should be words, and the values should be the appropriate tag string.
#
# The `MFCTagger` class is provided to mock the interface of Pomegranite HMM models so that they can be used interchangeably.

# %%
# Create a lookup table mfc_table where mfc_table[word] contains the tag label most frequently assigned to that word
from collections import namedtuple

FakeState = namedtuple("FakeState", "name")

class MFCTagger:
    # NOTE: You should not need to modify this class or any of its methods
    missing = FakeState(name="<MISSING>")
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))


# TODO: calculate the frequency of each tag being assigned to each word (hint: similar, but not
# the same as the emission probabilities) and use it to fill the mfc_table

word_counts = pair_counts(data.training_set.Y,data.training_set.X)

# %%
word_counts
# Out:
# {'.': {'!': 1300,
#   "'": 246,
#   "''": 7004,
#   '(': 1923,
#   ')': 1949,
#   ',': 46499,
#   '--': 2739,
#   '.': 39500,
#   ':': 1410,
#   ';': 4418,
#   '?': 3732,
#   '[': 2,
#   ']': 2,
#   '``': 7033},
#  'ADJ': {'infamous': 2,
#   'newly-emerging': 1,
#   'fine': 112,
#   'roughshod': 1,
#   'compensatory': 3,
#   'deadly': 14,
#   'Cooperative': 2,
#   'oleophobic': 1,
#   'scoreless': 1,
#   'open-collared': 1,
#   'all-pervading': 1,
#   'hemispherical': 1,
#   'trade-preparatory': 1,
#   'vaster': 1,
#   'unuttered': 1,
#   'lower-middle': 3,
#   'slow-moving': 1,
#   'monic': 3,
#   'congratulatory': 1,
#   'ikey-kikey': 1,
#   'foot-high': 1,
#   'former': 108,
#   'venerable': 4,
#   'month-long': 1,
#   'fine-chiseled': 1,
#   'tensional': 1,
#   'Ripe': 2,
#   '25th': 2,
#   'Polytechnic': 1,
#   'Minor': 5,
#   'self-deluded': 1,
#   'fragmentary': 6,
#   'Analytical': 5,
#   'staggering': 3,
#   'misshapen': 1,
#   'indestructible': 1,
#   'alkaline': 2,
#   'autobiographical': 3,
#   'three-man': 2,
#   'psychoanalytic': 5,
#   'heartbreaking': 1,
#   'pragmatic': 3,
#   'jovial': 1,
#   'mid-Victorian': 1,
#   'unpatriotic': 1,
#   'equal': 63,
#   'Distributive': 1,
#   'seventeenth': 7,
#   'purple-black': 1,
#   'complaisant': 1,
#   'retail': 7,
#   'puzzling': 7,
#   'thirtieth': 1,
#   'fancier': 1,
#   'non-violent': 8,
#   'jocular': 4,
#   'wall-stabilized': 1,
#   'contemptuous': 5,
#   'pivotal': 1,
#   'prone': 10,
#   'inappropriate': 3,
#   'precautionary': 2,
#   'unsold': 2,
#   'half-crazy': 1,
#   'Jewish': 59,
#   'regulatory': 2,
#   'uniformed': 5,
#   'metropolitan': 18,
#   '4th': 5,
#   'flimsy': 2,
#   'shoulder-high': 1,
#   'roundabout': 1,
#   'logistic': 2,
#   'Joint': 7,
#   'self-appointed': 3,
#   'new-found': 3,
#   'travelogue-like': 1,
#   'onetime': 1,
#   'naval': 16,
#   'fiber-coupled': 4,
#   'talismanic': 1,
#   'unwarranted': 3,
#   'glamorous': 4,
#   'bottom-living': 1,
#   'compact': 7,
#   'care-free': 1,
#   'unheard-of': 1,
#   'penultimate': 1,
#   'co-operative': 4,
#   'taut-nerved': 1,
#   'epigenetic': 1,
#   'brushy': 2,
#   'S.': 2,
#   'first-rate': 3,
#   'medico-military': 3,
#   'Linguistic': 1,
#   'eternal': 18,
#   'nine-chambered': 1,
#   'sharp-limbed': 1,
#   'delphic': 1,
#   'papal': 5,
#   '139-foot': 1,
#   'senior-graduate': 1,
#   'mid-twentieth': 3,
#   'Gentile-Jewish': 4,
#   'impervious': 1,
#   'concrete': 15,
#   'egg-sized': 1,
#   'conversational': 2,
#   'military': 144,
#   'cranelike': 1,
#   'ungracious': 1,
#   'flashy': 3,
#   'frank': 16,
#   'retrogressive': 1,
#   'naked': 22,
#   'non-supervisory': 3,
#   'new-rich': 1,
#   'irksome': 1,
#   'dilute': 1,
#   'wan': 2,
#   'stringy': 2,
#   'Englishy': 1,
#   'barbed': 1,
#   'mesenteric': 1,
#   'multivalent': 1,
#   'unyielding': 1,
#   '16-year-old': 1,
#   'acceptable': 15,
#   'heartfelt': 1,
#   'university-trained': 1,
#   'Holy': 28,
#   'monophonic': 1,
#   'pretentious': 6,
#   '16-mesh': 1,
#   'kinder': 1,
#   'eligible': 12,
#   'acidulous': 1,
#   'native': 31,
#   'long-stemmed': 1,
#   'Martian': 5,
#   'lovelorn': 1,
#   'bleacher-type': 1,
#   'divisible': 1,
#   'flamboyant': 2,
#   'numerous': 38,
#   'heliocentric': 1,
#   'rainbow-hued': 1,
#   'rankest': 1,
#   'elder': 7,
#   'neural': 3,
#   'three-round': 1,
#   'seven-hit': 1,
#   'waist-length': 1,
#   'declamatory': 1,
#   'brotherly': 2,
#   'nominal': 8,
#   'symptomatic': 5,
#   'celiac': 1,
#   'Electoral': 1,
#   'societal': 2,
#   'electronic': 57,
#   'hundred-and-eighty-degree': 1,
#   'unceasing': 1,
#   'nation-building': 1,
#   'Handmade': 1,
#   'quadripartite': 1,
#   'jazzy': 1,
#   'epic': 3,
#   'jocund': 1,
#   'world-famous': 3,
#   'amber': 2,
#   'mediumistic': 1,
#   'uneven': 4,
#   'peridontal': 1,
#   'guttural': 2,
#   'four-letter': 2,
#   'nearer': 4,
#   'yellow-green': 3,
#   'privileged': 10,
#   'blood-filled': 1,
#   'cortical': 3,
#   'war-ridden': 2,
#   'parklike': 1,
#   'memorable': 9,
#   'Chemical': 2,
#   'slender-waisted': 1,
#   'unprofessional': 1,
#   '23d': 5,
#   'nonpartisan': 1,
#   'state-sponsored': 1,
#   'German-language': 1,
#   'cutest': 1,
#   'stressful': 1,
#   'bullish': 1,
#   'Nutritious': 1,
#   'Future': 7,
#   'unreasonable': 3,
#   'organizational': 5,
#   'hable': 1,
#   'bashful': 1,
#   'Supreme': 22,
#   'leathery': 1,
#   'Famed': 1,
#   'supercilious': 1,
#   'morphologic': 1,
#   'nonlinguistic': 2,
#   'nicer': 1,
#   'zodiacal': 2,
#   'Alone': 1,
#   '51st': 1,
#   'Magnetic': 1,
#   'bear-like': 1,
#   'blue-green': 3,
#   'hysterical': 10,
#   'consistent': 20,
#   'infirm': 1,
#   'traditional': 57,
#   'self-conscious': 5,
#   'poly-unsaturated': 1,
#   'Iron': 1,
#   'far': 29,
#   'celestial': 3,
#   '25-year-old': 1,
#   'Doric': 3,
#   'less-hurried': 1,
#   'Unsuccessful': 1,
#   'slavish': 1,
#   'spiritual': 52,
#   'homozygous': 2,
#   'tangential': 1,
#   'Middle-South': 2,
#   'Strange': 7,
#   'unnoticed': 4,
#   'hearty': 4,
#   'subject': 30,
#   'dependent': 27,
#   'aforesaid': 1,
#   'tuxedoed': 1,
#   'blackest': 1,
#   'disobedient': 2,
#   'heavily-upholstered': 1,
#   '78th': 1,
#   'non-Catholic': 2,
#   'parrot-like': 1,
#   'lyrical': 6,
#   'coolest': 3,
#   'flashlight-type': 1,
#   'systematic': 11,
#   'carved-out-of-solid': 1,
#   'Herculean': 1,
#   'self-destructive': 2,
#   'loud': 10,
#   'general-appeal': 1,
#   'deft': 1,
#   'taller': 6,
#   'listless': 1,
#   'Organic': 1,
#   'unasterisked': 1,
#   'bacterial': 9,
#   'non-social': 1,
#   'Western-style': 1,
#   'foppish': 1,
#   'peripheral': 7,
#   'creedal': 1,
#   'intra-state': 1,
#   'Bogartian': 1,
#   'courageous': 4,
#   'rough-tough': 1,
#   'sudden-end': 1,
#   'gregarious': 4,
#   'unremitting': 1,
#   'stanch': 1,
#   'Botulinal': 1,
#   'puissant': 2,
#   'overgenerous': 1,
#   'submarine': 9,
#   'red-blooded': 1,
#   'academic': 45,
#   'lawmaking': 1,
#   'Virgin': 2,
#   'later': 46,
#   'honest': 39,
#   'inborn': 1,
#   'electrifying': 1,
#   '40-year-old': 2,
#   'straight': 40,
#   'pointed': 2,
#   'Hatless': 1,
#   'available': 201,
#   "rockin'": 1,
#   'bimonthly': 1,
#   'unarmed': 4,
#   'South': 60,
#   'uncommunicative': 1,
#   'Thermal': 1,
#   'inexplicable': 5,
#   'perverse': 3,
#   'durable': 10,
#   'grovelike': 1,
#   'familiar': 61,
#   'gas-fired': 1,
#   'important': 286,
#   'esoteric': 4,
#   'executive': 8,
#   'flat-bottomed': 3,
#   'focal': 7,
#   'largely-silent': 1,
#   'clumsy': 6,
#   'upward-mobile': 2,
#   'white-dominated': 1,
#   'lame': 2,
#   'sulky': 4,
#   'monoclinic': 1,
#   'expendable': 1,
#   'left-of-center': 1,
#   'liberal': 45,
#   'closely-packed': 1,
#   'careless': 6,
#   '25-liter': 1,
#   'metamorphic': 1,
#   'water-proof': 1,
#   'Utopian': 10,
#   'sky-carving': 1,
#   'unannounced': 2,
#   '5-run': 1,
#   'adamant': 3,
#   'palatable': 1,
#   'battery-powered': 2,
#   'two-digit': 3,
#   'airborne': 5,
#   'non-figurative': 1,
#   'hypnotic': 1,
#   'tsunami-warning': 1,
#   'pre-historic': 1,
#   'hard-nosed': 1,
#   'sub-freezing': 1,
#   'gross': 17,
#   'nine-year': 1,
#   'hazardous': 4,
#   'just': 12,
#   'light-reflecting': 1,
#   '8-channel': 1,
#   'psychosomatic': 1,
#   'Norwegian': 2,
#   'syrupy': 2,
#   'safer': 3,
#   'Varian': 2,
#   'characteristic': 38,
#   'metrical': 2,
#   'dull-gray': 1,
#   'superhuman': 1,
#   'post-Inaugural': 1,
#   'deep-set': 3,
#   'juicy': 4,
#   'fussy': 3,
#   'muddy': 9,
#   'deathward': 1,
#   'binding': 1,
#   'half-digested': 1,
#   'darkling': 1,
#   'Communist': 20,
#   'problematical': 1,
#   'structural': 17,
#   'crack': 1,
#   'adhesive': 2,
#   'Wild': 5,
#   'Fifty-ninth': 1,
#   'unobtainable': 1,
#   'deceitful': 1,
#   'enviable': 2,
#   'fusiform': 1,
#   'illusive': 2,
#   'ashamed': 10,
#   'convertible': 7,
#   'defensive': 15,
#   'redemptive': 1,
#   'radiant': 4,
#   'unpaved': 1,
#   'Hypothalamic': 1,
#   'disaffiliated': 1,
#   'canny': 2,
#   'oversize': 1,
#   'unable': 42,
#   'clattery': 1,
#   "'nough": 1,
#   'suggestive': 4,
#   'rosy-fingered': 1,
#   'freehand': 2,
#   'folksy': 2,
#   'Serious': 2,
#   'eye-undeceiving': 2,
#   'incarnate': 1,
#   'impeccable': 4,
#   'Publick': 2,
#   'allegorical': 3,
#   'ecumenical': 22,
#   'lucrative': 2,
#   'hectic': 2,
#   'well-balanced': 1,
#   'Northwestern': 4,
#   'fetching': 2,
#   'godlike': 1,
#   'Same': 4,
#   'kapok-filled': 1,
#   'subtle': 17,
#   'pug-nosed': 1,
#   'wood-grained': 1,
#   'transmissible': 1,
#   'western-style': 1,
#   'acrobatic': 1,
#   'hypothetical': 7,
#   'thoughtful': 7,
#   'self-unloading': 4,
#   'aft': 1,
#   'sympathetic': 30,
#   'brackish': 3,
#   'injurious': 2,
#   'obsessive-compulsive': 1,
#   'geographic': 3,
#   '24-sheet': 1,
#   'abundant': 5,
#   'drowsy': 1,
#   'Rear': 1,
#   'anastomotic': 1,
#   'on-the-job': 1,
#   'first-hand': 2,
#   'wide-awake': 1,
#   'Universal-International': 1,
#   'serological': 1,
#   'ceremonial': 2,
#   'draughty': 1,
#   'prescriptive': 1,
#   'ghostly': 2,
#   'unearned': 1,
#   'darker': 1,
#   '205-pound': 1,
#   'hatchet-faced': 1,
#   'buccolic': 1,
#   'three-wood': 1,
#   'recoilless': 2,
#   'sober': 14,
#   'problem-solving': 2,
#   'shadowy': 1,
#   'atune': 1,
#   'mental': 32,
#   'Darkling': 1,
#   'above': 19,
#   'Atomic': 7,
#   'doctrinal': 2,
#   'brimful': 1,
#   'hoarse': 4,
#   'biological': 13,
#   'feline': 2,
#   'belligerent': 5,
#   'unattractive': 3,
#   'ante-bellum': 3,
#   'undetermined': 2,
#   'semitropical': 1,
#   'unnameable': 1,
#   'distressing': 7,
#   'best-looking': 1,
#   'overbearing': 1,
#   '600-yard': 1,
#   'unpartisan': 1,
#   'angriest': 1,
#   'eighth': 16,
#   'wearisome': 2,
#   'stochastic': 1,
#   'phony': 10,
#   'irresolute': 2,
#   'Orthodontic': 1,
#   'recumbent': 1,
#   'American': 421,
#   'Guatemalan': 1,
#   'mythological': 10,
#   'sublunary': 1,
#   'mysterious': 21,
#   'standby': 1,
#   'Communist-led': 1,
#   'rockbound': 1,
#   'Double': 1,
#   'molecular': 14,
#   'Crimean': 1,
#   'Automatic': 1,
#   'philosophical': 19,
#   'chunky': 1,
#   'Italian': 37,
#   'prurient': 1,
#   'ninetieth': 1,
#   'grey-skied': 1,
#   'deserving': 1,
#   '900-calorie': 1,
#   'tube-nosed': 1,
#   'blunter': 1,
#   'insubordinate': 2,
#   'frivolous': 4,
#   'unlovely': 1,
#   'kittenish': 1,
#   'historical': 51,
#   'finicky': 1,
#   'ingratiating': 3,
#   'force-fear': 1,
#   'tightest': 2,
#   'bright': 63,
#   'single-valued': 5,
#   'British': 84,
#   'nonviolent': 1,
#   'rainless': 1,
#   'slow': 42,
#   'eloquent': 10,
#   'wishful': 7,
#   'collosal': 1,
#   'miscellaneous': 5,
#   'antique': 1,
#   'burdensome': 1,
#   'florid': 2,
#   'Central': 51,
#   'vertical': 13,
#   'Southeast': 10,
#   'dextrous-fingered': 1,
#   'quadric': 4,
#   '40-grain': 1,
#   'planoconcave': 1,
#   'grave': 16,
#   'finite-dimensional': 3,
#   'chainlike': 1,
#   'Faint': 1,
#   'impurity-doped': 1,
#   'cathodophoretic': 1,
#   'unasked': 2,
#   'half-crocked': 1,
#   'jubilant': 2,
#   'myriad': 4,
#   'shallow': 12,
#   'unstable': 7,
#   'synergistic': 1,
#   'heathen': 1,
#   'semiarid': 1,
#   'unachievable': 1,
#   'Super': 1,
#   'silvery': 1,
#   'Input/Output': 2,
#   'ample': 13,
#   'resourceful': 2,
#   'helpless': 14,
#   'shabby': 4,
#   'aloof': 2,
#   'comely': 1,
#   'nociceptive': 2,
#   'Pure': 2,
#   'Indirect': 1,
#   'atomic': 26,
#   'accountable': 1,
#   'illustrative': 4,
#   'green-scaled': 1,
#   'eastern': 7,
#   'chest-back-shoulder': 1,
#   'first-class': 4,
#   'symmetric': 6,
#   'luscious': 2,
#   'lighter': 7,
#   'onrushing': 1,
#   'atypical': 1,
#   'three-panel': 1,
#   'well-meaning': 3,
#   'conspiratorial': 1,
#   'moderate': 17,
#   'tactual': 7,
#   'beetling': 1,
#   'well-publicized': 1,
#   'ideal': 41,
#   'graceful': 5,
#   'Twenty-one-year-old': 1,
#   'comfortable': 27,
#   'earthy': 7,
#   'chemical': 5,
#   'senseless': 5,
#   'Afraid': 2,
#   'Slow': 1,
#   'unpublished': 2,
#   "p'lite": 1,
#   'suspect': 1,
#   'Mighty': 2,
#   'blood-soaked': 1,
#   'fifty-dollar': 1,
#   'ponderous': 3,
#   'unbelieving': 1,
#   'well-known': 11,
#   'inclement': 1,
#   'interpretative': 1,
#   'faithful': 8,
#   'intermolecular': 1,
#   'last': 462,
#   'striking': 24,
#   'Newest': 3,
#   'wraith-like': 2,
#   'intactible': 1,
#   'discreet': 2,
#   'threatening': 3,
#   'higher': 107,
#   'roughest': 1,
#   'clear-cut': 6,
#   'charming': 17,
#   'profane': 1,
#   'unoccupied': 1,
#   'universal': 32,
#   'age-old': 4,
#   'sporadic': 5,
#   'Valuable': 1,
#   'fabled': 3,
#   'self-conceited': 1,
#   'high-salaried': 1,
#   'uncanny': 4,
#   'fast-closing': 2,
#   'refractive': 1,
#   'Miltonic': 1,
#   'ribonucleic': 1,
#   'cross-sectional': 4,
#   'Canadian': 4,
#   'interfaith': 5,
#   'last-mentioned': 1,
#   'monetary': 7,
#   'trouble-free': 1,
#   'listener-supported': 1,
#   'high-up': 1,
#   'frightful': 6,
#   'unused': 3,
#   'natal': 2,
#   'Greek-speaking': 1,
#   'multi-state': 1,
#   'small': 414,
#   'manye': 1,
#   'unsatisfactory': 5,
#   'double-valued': 1,
#   'undeclared': 1,
#   'unleveled': 1,
#   "dam'": 1,
#   'oblong': 1,
#   'okay': 3,
#   'slash-mouthed': 1,
#   'sincere': 13,
#   'cultural': 40,
#   'neon-lit': 1,
#   'trail-worn': 1,
#   'cognizant': 2,
#   'newest': 10,
#   'modernistic': 1,
#   'unlawful': 1,
#   'terminal': 8,
#   'thyrotrophic': 1,
#   'self-centered': 1,
#   'newborn': 5,
#   'long-overdue': 1,
#   'fictional': 12,
#   'dimesize': 1,
#   'sweetest': 2,
#   'Israeli': 4,
#   'snazzy': 1,
#   'phosphate-buffered': 1,
#   'descriptive': 5,
#   'self-content': 1,
#   'Wider': 2,
#   'Spanish-American': 2,
#   'deadliest': 2,
#   'pre-nuptial': 1,
#   'Notable': 1,
#   'unnecessary': 9,
#   'survey-type': 2,
#   'arteriolar': 2,
#   'unreal': 6,
#   'significant': 70,
#   'Gothic': 3,
#   'totalitarian': 4,
#   'near-by': 2,
#   'purposeless': 1,
#   'brushlike': 1,
#   'indiscriminate': 2,
#   'salable': 1,
#   'biographical': 4,
#   '12-shot': 1,
#   'wet': 34,
#   'inexpensive': 3,
#   'nameless': 1,
#   'negligent': 1,
#   'cosmic': 15,
#   'guiltless': 1,
#   'terrifying': 2,
#   'anti-human': 1,
#   'dreamlike': 2,
#   '3-inch': 1,
#   'cost-finding': 1,
#   'snowy': 4,
#   'duller': 1,
#   'colicky': 1,
#   'narrative': 2,
#   'Crooked': 1,
#   'Comprehensive': 1,
#   'expository': 1,
#   'worldwide': 1,
#   'Preliminary': 2,
#   'N.': 1,
#   'Latest': 1,
#   'indebted': 8,
#   'flat-topped': 1,
#   'phonic': 1,
#   'oriental': 1,
#   'melodramatic': 3,
#   'bloodless': 2,
#   'Black': 13,
#   'warmed-over': 1,
#   'indescribable': 3,
#   'coincidental': 1,
#   'inalienable': 2,
#   'Prime': 4,
#   'protozoan': 1,
#   'uncluttered': 1,
#   'Typical': 1,
#   'nonionic': 1,
#   'sicker': 1,
#   'inopportune': 1,
#   'Capable': 2,
#   'then': 9,
#   'mad': 26,
#   'delicate': 23,
#   'dapper': 3,
#   'essential': 58,
#   'bestial': 1,
#   'sterile': 5,
#   'blind': 31,
#   'city-owned': 1,
#   'well-braced': 1,
#   'fluffy': 1,
#   'gritty-eyed': 1,
#   'Wooden': 1,
#   'bodily': 2,
#   'halfway': 3,
#   'Redundant': 1,
#   '24th': 6,
#   'camping-out': 1,
#   'timely': 4,
#   'noisier': 1,
#   'Rumanian': 1,
#   'Wrong': 1,
#   'quixotic': 1,
#   'Danish': 6,
#   '689-page': 1,
#   'female': 14,
#   'unbearable': 6,
#   'competitive': 25,
#   'two-class': 1,
#   'agile': 1,
#   'fervent': 4,
#   'inharmonious': 1,
#   'inhibitory': 2,
#   'Arctic': 2,
#   'static': 11,
#   'differentiable': 1,
#   'plaintive': 1,
#   'expeditious': 2,
#   'rock-ribbed': 1,
#   'future-day': 1,
#   'gawky': 1,
#   'unique': 45,
#   'cerulean': 1,
#   'Wooded': 1,
#   'gargantuan': 1,
#   'revenge-seeking': 1,
#   'spring-back': 1,
#   'livable': 1,
#   'voluminous': 3,
#   'labor-based': 1,
#   'earthly': 6,
#   'won-lost': 1,
#   'middle': 36,
#   'vertebral': 2,
#   '24-inch': 1,
#   'Sharp': 1,
#   'crummy': 3,
#   'open-handed': 1,
#   'ten-year': 2,
#   'collectible': 1,
#   '24-hour': 1,
#   'hateful': 3,
#   'unreliable': 3,
#   'tyrannical': 1,
#   'adroit': 1,
#   'beige': 1,
#   '700-mile': 1,
#   'ship-to-surface': 1,
#   '5-game': 1,
#   'aforementioned': 1,
#   'slim-waisted': 1,
#   'simple': 118,
#   'formative': 1,
#   'collar': 1,
#   'handsome': 28,
#   'terror-stricken': 1,
#   'hitless': 1,
#   'Permian': 1,
#   'faint': 21,
#   'Gaussian': 1,
#   'three-part': 3,
#   'puny': 4,
#   'manly': 2,
#   'bedfast': 1,
#   'limpid': 1,
#   'curtained': 1,
#   'eighty-fifth': 1,
#   'sinewy': 2,
#   'semi-serious': 1,
#   '24-in.': 1,
#   'mammoth': 4,
#   'socal': 1,
#   'hand-painted': 1,
#   'bizarre': 4,
#   'unimpressive': 2,
#   'paunchy': 2,
#   'Colombian': 1,
#   'junior-senior': 1,
#   'half-expressed': 1,
#   'papillary': 1,
#   'vacant': 10,
#   'speedy': 5,
#   'Dauntless': 1,
#   'monaural': 1,
#   'nerveless': 1,
#   'swell': 2,
#   'stupid': 18,
#   'false': 18,
#   '5-mile': 1,
#   'Incapable': 1,
#   'well-designed': 2,
#   'groundless': 1,
#   'vibrant': 3,
#   'attractive': 33,
#   'cockier': 1,
#   'Hard-surface': 1,
#   'Vigorous': 1,
#   'recognizable': 6,
#   'clever': 12,
#   'unequaled': 1,
#   'red-turbaned': 1,
#   'pathological': 8,
#   'proportional': 9,
#   '80-hp': 1,
#   'melodic': 4,
#   'teen-age': 3,
#   'scraggly': 1,
#   'uncaused': 1,
#   'Movable': 1,
#   'uncontrollable': 1,
#   'fractious': 1,
#   'Emotional': 1,
#   'Ironic': 1,
#   'nautical': 1,
#   'scanty': 4,
#   'Cuban': 11,
#   'indicative': 5,
#   'monsoon-shrouded': 1,
#   'barometric': 1,
#   'drugless': 1,
#   'agrarian': 3,
#   'bifocal': 1,
#   'super-charged': 1,
#   'inapt': 1,
#   'university-educated': 1,
#   'productive': 18,
#   'Peruvian': 2,
#   'institution-wide': 1,
#   'exuberant': 7,
#   'put-upon': 1,
#   'experiential': 3,
#   'domestic': 52,
#   'slimmer': 1,
#   'callous': 4,
#   'vaguely-imagined': 1,
#   'alone': 6,
#   'Anglo-Protestant': 1,
#   'macabre': 1,
#   'tactical': 5,
#   'incandescent': 3,
#   'Religious': 7,
#   'antithyroid': 5,
#   'transitional': 4,
#   'wasteful': 6,
#   'bomb-proof': 1,
#   'seeming': 2,
#   'epicyclical': 1,
#   'Gross': 8,
#   'two-part': 1,
#   'Thirty-ninth': 1,
#   'illegal': 7,
#   'indefensible': 2,
#   'syntactic': 1,
#   'vicious': 11,
#   'non-military': 2,
#   'vine-shaded': 1,
#   'unperceived': 1,
#   '12-inch': 1,
#   'less': 176,
#   'harrowing': 1,
#   '18th': 4,
#   'cubic': 13,
#   'unalterable': 1,
#   'indistinguishable': 3,
#   'north-south': 1,
#   'cost-raising': 2,
#   'non-negative': 1,
#   'tough': 28,
#   'neuromuscular': 1,
#   'Whole': 2,
#   'diurnal': 3,
#   'anarchical': 2,
#   'rank': 1,
#   'moody': 1,
#   'perceptual': 7,
#   'schoolgirlish': 1,
#   'chromatographic': 3,
#   'minimum': 33,
#   'adjectival': 1,
#   'rough-hewn': 1,
#   'Atlantic': 25,
#   'Kohnstamm-negative': 8,
#   'third-': 1,
#   'polygynous': 1,
#   'Europeanish': 1,
#   'Ridiculous': 1,
#   'brightest': 2,
#   'Subject': 1,
#   'thermal': 24,
#   'cu.': 4,
#   'Better': 4,
#   'tacit': 1,
#   'suitable': 29,
#   'south-eastern': 1,
#   'effortless': 1,
#   'Strong': 6,
#   'junior-philosophical': 1,
#   'unhurried': 2,
#   'bugeyed': 1,
#   'timeworn': 1,
#   'credible': 2,
#   'foster': 1,
#   'Eastern': 16,
#   'industrious': 3,
#   'eye-filling': 1,
#   'uncommon': 5,
#   'exponential': 1,
#   'fat-soluble': 1,
#   'complementary': 3,
#   'Good': 32,
#   'two-step': 1,
#   'Nameless': 1,
#   'transoceanic': 1,
#   'proportionate': 7,
#   'dry-eyed': 1,
#   'rebellious': 2,
#   'leaderless': 1,
#   'everyday': 12,
#   'hard-boiled': 1,
#   'Bio-Dynamic': 1,
#   'sophisticated': 24,
#   'world-shaking': 2,
#   'ecclesiastical': 5,
#   'West': 72,
#   'terra-cotta-colored': 1,
#   'allowable': 4,
#   'well-ruled': 1,
#   'ash-blonde': 1,
#   'earliest': 17,
#   'Bizarre': 1,
#   '2-year-old': 2,
#   'bit-like': 1,
#   'tops': 1,
#   'northern': 15,
#   'saline': 6,
#   'ice-feeling': 1,
#   'resplendent': 1,
#   'sales-conscious': 1,
#   'oleophilic': 3,
#   'swivel': 1,
#   'five-ply': 1,
#   'regular-featured': 1,
#   'unformed': 1,
#   'punishable': 1,
#   'burlesque': 1,
#   'painted-in': 1,
#   'present': 179,
#   'loquacious': 2,
#   'workmanlike': 2,
#   'cozy': 1,
#   'Aristotelian': 2,
#   'undependable': 2,
#   'sociable': 1,
#   'out-of-bounds': 1,
#   'well-bound': 1,
#   'effective': 94,
#   'all-powerful': 1,
#   'impertinent': 1,
#   ...},
#  'ADP': {"'bout": 1,
#   "'cept": 1,
#   "'ceptin'": 1,
#   "'fore": 1,
#   "'round": 1,
#   "'till": 1,
#   '-': 51,
#   '/': 17,
#   '2': 1,
#   ':': 19,
#   'About': 4,
#   'Above': 16,
#   'According': 26,
#   'Across': 4,
#   'After': 191,
#   'Against': 6,
#   'Along': 6,
#   'Although': 97,
#   'Amid': 2,
#   'Among': 39,
#   'Around': 5,
#   'As': 376,
#   'At': 331,
#   'Because': 32,
#   'Before': 56,
#   'Behind': 10,
#   'Below': 6,
#   'Beneath': 3,
#   'Beside': 1,
#   'Besides': 13,
#   'Between': 13,
#   'Beyond': 11,
#   'But': 3,
#   'By': 160,
#   'Concerning': 2,
#   'Considering': 5,
#   'Depending': 1,
#   'Despite': 28,
#   'Down': 2,
#   'During': 110,
#   'Except': 9,
#   'For': 522,
#   'From': 128,
#   'Fur': 1,
#   'If': 586,
#   'In': 1426,
#   'Including': 1,
#   'Inside': 3,
#   'Into': 3,
#   'Like': 41,
#   'Near': 7,
#   'Next': 4,
#   'Notwithstanding': 1,
#   'Of': 268,
#   'Off': 1,
#   'On': 279,
#   'Once': 26,
#   'Opposite': 2,
#   'Out': 12,
#   'Outside': 3,
#   'Over': 13,
#   'Past': 1,
#   'Pending': 1,
#   'Per': 1,
#   'Plus': 1,
#   'Rather': 2,
#   'Regarding': 1,
#   'Respecting': 1,
#   'Save': 1,
#   'Since': 135,
#   'So': 44,
#   'Than': 2,
#   'That': 36,
#   'Though': 52,
#   'Through': 23,
#   'Throughout': 18,
#   'Thru': 1,
#   'Till': 3,
#   'To': 140,
#   'Toward': 6,
#   'Towards': 2,
#   'Uh': 1,
#   'Under': 46,
#   'Underneath': 3,
#   'Unless': 11,
#   'Unlike': 8,
#   'Until': 21,
#   'Up': 3,
#   'Upon': 16,
#   'Whereas': 10,
#   'Whether': 21,
#   'While': 96,
#   'With': 220,
#   'Within': 31,
#   'Without': 30,
#   'Yff': 1,
#   'aboard': 8,
#   'about': 972,
#   'above': 133,
#   'according': 81,
#   'across': 202,
#   'after': 643,
#   'aftuh': 1,
#   'against': 491,
#   'albeit': 1,
#   'along': 149,
#   'alongside': 8,
#   'altho': 2,
#   'although': 152,
#   'amid': 9,
#   'amidst': 3,
#   'among': 258,
#   'amongst': 4,
#   'anti': 1,
#   'around': 249,
#   'as': 4542,
#   'astride': 3,
#   'at': 3997,
#   'atop': 2,
#   'att': 2,
#   'because': 527,
#   'beefore': 1,
#   'before': 634,
#   'behahn': 1,
#   'behind': 171,
#   'behynde': 1,
#   'below': 61,
#   'beneath': 44,
#   'beside': 57,
#   'besides': 14,
#   'between': 574,
#   'beyond': 118,
#   'bi': 2,
#   'bout': 1,
#   'but': 99,
#   'by': 4051,
#   'concerning': 45,
#   "considerin'": 1,
#   'considering': 12,
#   'consisting': 2,
#   'depending': 19,
#   'despite': 51,
#   'down': 151,
#   "durin'": 1,
#   'during': 358,
#   'ere': 1,
#   'except': 137,
#   'excepting': 1,
#   'excluding': 10,
#   "f'ovuh": 1,
#   "f'r": 1,
#   'fer': 2,
#   'following': 11,
#   'for': 6979,
#   'from': 3393,
#   'if': 1157,
#   'in': 15278,
#   'including': 118,
#   'infra': 1,
#   'inside': 58,
#   'inter': 1,
#   'into': 1420,
#   'involving': 3,
#   'lahk': 1,
#   'lak': 1,
#   'lest': 12,
#   'like': 795,
#   'minus': 4,
#   'near': 118,
#   'nearer': 1,
#   'nearest': 1,
#   'next': 30,
#   'notwithstanding': 2,
#   "o'": 10,
#   "o'er": 1,
#   'of': 28772,
#   'off': 124,
#   'on': 4742,
#   'once': 47,
#   'onct': 1,
#   'onto': 48,
#   'opposite': 15,
#   'out': 340,
#   'outside': 65,
#   'over': 676,
#   'past': 54,
#   'pending': 4,
#   'per': 305,
#   'plus': 13,
#   'post': 3,
#   'pro': 5,
#   'providing': 3,
#   'pursuant': 17,
#   'rather': 92,
#   'regarding': 26,
#   'respecting': 1,
#   'round': 3,
#   "s'posin'": 1,
#   'save': 4,
#   'seeing': 1,
#   'since': 342,
#   'so': 336,
#   "so's": 4,
#   'spite': 8,
#   'supposing': 1,
#   'synce': 1,
#   "t'hi-im": 1,
#   'than': 1434,
#   'that': 5194,
#   'thatt': 1,
#   'then': 1,
#   'thet': 1,
#   "tho'": 1,
#   'though': 269,
#   'through': 713,
#   'throughout': 91,
#   'thru': 9,
#   'till': 31,
#   'times': 2,
#   'to': 8809,
#   'toward': 312,
#   'towardes': 1,
#   'towards': 52,
#   'under': 492,
#   'underneath': 4,
#   'unless': 64,
#   'unlike': 27,
#   'until': 351,
#   'unto': 13,
#   'up': 146,
#   'upon': 338,
#   'uppon': 3,
#   'v.': 11,
#   'versus': 9,
#   'via': 11,
#   'vis-a-vis': 2,
#   'vs.': 13,
#   'whereas': 25,
#   'whereupon': 6,
#   'whether': 207,
#   'while': 378,
#   'with': 5610,
#   'within': 245,
#   'without': 441,
#   'yff': 1},
#  'ADV': {'fine': 3,
#   'persistently': 3,
#   'temporarily': 17,
#   'whereby': 17,
#   'rigidly': 8,
#   'Pretty': 3,
#   'unconsciously': 7,
#   'plenty': 5,
#   'thereby': 28,
#   'ridiculously': 2,
#   'Highly': 1,
#   'encouragingly': 1,
#   'paternally': 1,
#   'superficially': 3,
#   'equally': 51,
#   'eastward': 3,
#   'primly': 1,
#   'inadequately': 2,
#   'P.M.': 6,
#   'Vastly': 1,
#   'dearly': 3,
#   'doubtless': 9,
#   'Long': 2,
#   'upon': 28,
#   'more': 968,
#   'smilingly': 1,
#   'Biblically': 1,
#   'beautifully': 11,
#   'hardest': 1,
#   'any': 12,
#   'healthily': 1,
#   'thence': 5,
#   'anyways': 1,
#   'forcibly': 2,
#   'openly': 30,
#   'restively': 1,
#   'judiciously': 1,
#   'systematically': 8,
#   'bleakly': 2,
#   'specifically': 29,
#   'responsively': 1,
#   'Paradoxically': 3,
#   'admiringly': 1,
#   'partially': 18,
#   'altruistically': 1,
#   'overwhelmingly': 7,
#   'rightly': 4,
#   'mournfully': 1,
#   'cohesively': 1,
#   'clearly': 92,
#   'occasionally': 30,
#   'predominately': 1,
#   'Nearly': 5,
#   'yet': 173,
#   'ashore': 6,
#   'Nearby': 1,
#   'Typically': 3,
#   'admittedly': 2,
#   'Compassionately': 1,
#   'gravely': 6,
#   'energetically': 2,
#   'lastly': 1,
#   'Strangely': 1,
#   'totally': 19,
#   'classically': 2,
#   'understandably': 3,
#   'tactually': 1,
#   'So': 140,
#   'Indeed': 33,
#   'studiously': 1,
#   'genuinely': 8,
#   'yearly': 4,
#   'prone': 3,
#   'sharply': 25,
#   'grudgingly': 6,
#   'fastest': 1,
#   'specially': 6,
#   'pungently': 1,
#   'right': 156,
#   'half-heartedly': 1,
#   'absurdly': 1,
#   'orally': 1,
#   'attentively': 1,
#   'aimlessly': 1,
#   'recently': 88,
#   'harder': 14,
#   'warmly': 7,
#   'hastily': 11,
#   'elaborately': 6,
#   'sure': 14,
#   'geometrically': 1,
#   'generously': 7,
#   'upstairs': 19,
#   'nakedly': 1,
#   'starkly': 1,
#   'Properly': 1,
#   'about': 422,
#   'scientifically': 4,
#   'chronically': 1,
#   'in-state': 1,
#   'Mathematically': 1,
#   'hyperbolically': 1,
#   'Commonly': 1,
#   'faster': 12,
#   'how': 482,
#   'where': 677,
#   'unobtrusively': 1,
#   'crucially': 1,
#   'heatedly': 1,
#   'Half': 2,
#   'under': 9,
#   'invisibly': 2,
#   'Due': 1,
#   'visually': 3,
#   'prayerfully': 1,
#   'wrongly': 1,
#   'soaking': 3,
#   'mutually': 9,
#   'stupidly': 2,
#   'overboard': 8,
#   'best': 43,
#   'Significantly': 3,
#   'closely': 53,
#   'incidentally': 4,
#   'dynamically': 1,
#   'incredibly': 6,
#   'protectively': 1,
#   'diagonally': 3,
#   'efficaciously': 2,
#   'authoritatively': 1,
#   'comparatively': 9,
#   'Possibly': 3,
#   'eerily': 2,
#   'sedately': 2,
#   'point-blank': 1,
#   'Yet': 51,
#   'alongside': 3,
#   'nicely': 8,
#   'Mainly': 2,
#   'especially': 116,
#   'impossibly': 1,
#   'mortally': 1,
#   'rectlinearly': 1,
#   'More': 15,
#   'curiously': 7,
#   'advisedly': 1,
#   'woefully': 1,
#   'tartly': 1,
#   'hilariously': 1,
#   'profusely': 3,
#   'austerely': 1,
#   'Microscopically': 3,
#   'frankly': 9,
#   'independently': 10,
#   'absently': 4,
#   'already': 215,
#   'consequently': 12,
#   'piecewise': 1,
#   'qualitatively': 1,
#   'inconspicuously': 1,
#   'alternately': 6,
#   'mercifully': 2,
#   'brightest': 1,
#   'snugly': 2,
#   'overseas': 8,
#   'internationally': 3,
#   'Well': 21,
#   'listlessly': 1,
#   'rotationally': 1,
#   'Less': 5,
#   'crudely': 2,
#   'dispassionately': 1,
#   'narrowly': 6,
#   'Merely': 2,
#   'prickly': 1,
#   'directionally': 1,
#   'eclectically': 1,
#   'Jist': 2,
#   'prettily': 2,
#   'unwisely': 2,
#   'unselfishly': 1,
#   'Damn': 1,
#   'extra': 2,
#   'price-wise': 1,
#   'rationally': 2,
#   'only': 1032,
#   'sooner': 10,
#   'wolfishly': 1,
#   'Dimly': 1,
#   'Thoroughly': 1,
#   'grammatically': 1,
#   'huskily': 1,
#   'electrically': 1,
#   'expectedly': 1,
#   'innocently': 2,
#   'wordlessly': 1,
#   'Maybe': 55,
#   'Rather': 9,
#   'relentlessly': 3,
#   'inversely': 4,
#   'nearer': 7,
#   'Clearly': 7,
#   'onwards': 1,
#   'confidently': 1,
#   'Frequently': 6,
#   'except': 6,
#   'suddenly': 111,
#   'First': 33,
#   'piously': 1,
#   'Admirably': 1,
#   'casually': 10,
#   'instrumentally': 3,
#   'full-time': 1,
#   'between': 1,
#   'no-o': 1,
#   'arbitrarily': 4,
#   'fairly': 47,
#   'approvingly': 1,
#   'unreasonably': 1,
#   'Unfortunately': 14,
#   'a-la-Aristotle': 1,
#   'empirically': 4,
#   'internally': 3,
#   'nearly': 103,
#   'Mostly': 5,
#   'derisively': 1,
#   'Essentially': 3,
#   'Finally': 44,
#   'bitterly': 12,
#   'largely': 57,
#   'better': 129,
#   'strangely': 3,
#   'musically': 1,
#   'painlessly': 1,
#   'Alone': 2,
#   'thither': 1,
#   'overly': 7,
#   'here': 479,
#   'fearfully': 3,
#   'downwind': 1,
#   'However': 135,
#   'uselessly': 1,
#   'Feverishly': 1,
#   'improbably': 1,
#   'organizationally': 1,
#   'noticeably': 2,
#   'Largely': 1,
#   'lazily': 1,
#   'Unanimously': 1,
#   'far': 298,
#   'algebraically': 3,
#   'Prior': 5,
#   'piecemeal': 1,
#   'downward': 4,
#   'Enthusiastically': 1,
#   'Yeah': 13,
#   'hurriedly': 2,
#   'furtively': 1,
#   'calmly': 6,
#   'tirelessly': 1,
#   'briskly': 3,
#   'Economically': 1,
#   'Astonishingly': 1,
#   'partly': 40,
#   'aforesaid': 1,
#   'Forever': 2,
#   'lot': 1,
#   'slyly': 2,
#   'advantageously': 1,
#   'Recently': 12,
#   'solidly': 9,
#   'justifiably': 5,
#   'Someday': 4,
#   'Ever': 11,
#   'gloomily': 2,
#   'approximately': 51,
#   'Whenever': 12,
#   'graciously': 3,
#   'ordinarily': 11,
#   'proudly': 8,
#   'correctly': 9,
#   'chronologically': 1,
#   'cruelly': 3,
#   'loud': 4,
#   'altogether': 20,
#   'staggeringly': 1,
#   'sensitively': 1,
#   'Furthermore': 32,
#   'statewide': 2,
#   'marginally': 1,
#   'upright': 5,
#   'westward': 8,
#   'Apart': 10,
#   'even': 749,
#   'upland': 1,
#   'compassionately': 1,
#   'lengthwise': 2,
#   'Impatiently': 1,
#   'widespread': 1,
#   'Real': 2,
#   'randomly': 1,
#   'prodigally': 1,
#   'Kinda': 1,
#   'formidably': 1,
#   'maliciously': 1,
#   'cynically': 1,
#   'covertly': 1,
#   'crazily': 2,
#   'thoroughly': 32,
#   'consciously': 9,
#   'darned': 1,
#   'steady': 3,
#   'drastically': 7,
#   'lively': 3,
#   'offshore': 1,
#   'besides': 8,
#   'Characteristically': 1,
#   'precariously': 2,
#   'later': 248,
#   'loosely': 8,
#   'straight': 47,
#   'purposefully': 1,
#   'highest': 4,
#   'with': 3,
#   'blithely': 3,
#   'again': 416,
#   'positively': 7,
#   'South': 1,
#   'succinctly': 1,
#   'thermodynamically': 2,
#   'explicitly': 5,
#   'anachronistically': 1,
#   'darkly': 2,
#   'measurably': 1,
#   'mainly': 28,
#   'provocatively': 1,
#   'along': 120,
#   'Again': 40,
#   'Sometimes': 42,
#   'intuitively': 1,
#   'No-o-o': 1,
#   'flamboyantly': 1,
#   'close': 75,
#   'expansively': 1,
#   'enduringly': 1,
#   'faintly': 5,
#   'consisently': 1,
#   'weakly': 3,
#   'shore': 1,
#   'commonly': 20,
#   'severely': 9,
#   'furiously': 11,
#   'ineptly': 1,
#   'syntactically': 1,
#   'Earlier': 3,
#   'unfairly': 2,
#   'according': 7,
#   'likely': 22,
#   'consistently': 18,
#   'lightly': 26,
#   'variously': 4,
#   'Physically': 2,
#   'somewheres': 1,
#   'outwardly': 2,
#   'overtly': 3,
#   'Likewise': 5,
#   'man-to-man': 1,
#   'triumphantly': 8,
#   'Rarely': 2,
#   'Dearly': 1,
#   'associatively': 1,
#   'Strictly': 1,
#   'emotionally': 7,
#   'Seldom': 1,
#   'Interestingly': 1,
#   'just': 584,
#   'sternly': 3,
#   'against': 2,
#   'wetly': 1,
#   'passively': 1,
#   'Down': 2,
#   'diametrically': 2,
#   'substantively': 1,
#   'callously': 1,
#   'stunningly': 1,
#   'comically': 1,
#   'girlishly': 2,
#   'squarely': 6,
#   'Swiftly': 1,
#   'seekingly': 1,
#   'uniquely': 7,
#   'yearningly': 1,
#   'fervently': 2,
#   'eventshahleh': 1,
#   'professionally': 2,
#   'badly': 26,
#   'ostensibly': 1,
#   'nawt': 1,
#   'shrewdly': 2,
#   'compactly': 1,
#   'Never': 27,
#   'urgently': 5,
#   'inshore': 1,
#   'spiritually': 5,
#   'lopsidedly': 1,
#   'Right': 5,
#   'unanimously': 10,
#   'unsmilingly': 1,
#   'oftener': 1,
#   'favorably': 13,
#   'carelessly': 2,
#   'predictably': 1,
#   'selectively': 2,
#   'unhesitatingly': 2,
#   'greatly': 52,
#   'Below': 5,
#   'racially': 1,
#   'equitably': 2,
#   'fascinatingly': 1,
#   'afar': 2,
#   'chemically': 4,
#   'tangibly': 1,
#   'somewhat': 99,
#   'comfortably': 9,
#   'Easy': 2,
#   'Surprisingly': 1,
#   'asymmetrically': 1,
#   'impeccably': 2,
#   'Sooner': 2,
#   'freehand': 1,
#   'dogmatically': 2,
#   'twirlingly': 1,
#   'louder': 1,
#   'previous': 2,
#   'mutely': 2,
#   'fair': 1,
#   'trustingly': 1,
#   'Relentlessly': 1,
#   'impersonally': 1,
#   'earlier': 53,
#   'alarmingly': 1,
#   'unfailingly': 1,
#   'completely': 85,
#   'entirely': 71,
#   'quickly': 72,
#   'vainly': 1,
#   'continually': 21,
#   'singlehandedly': 1,
#   'greedily': 1,
#   'Instead': 31,
#   'dutifully': 2,
#   'defiantly': 2,
#   'Why': 114,
#   'constructively': 2,
#   'Carefully': 3,
#   'intellectually': 3,
#   'underfoot': 3,
#   'slimly': 1,
#   'inasmuch': 1,
#   'hypothalamically': 1,
#   'infrequently': 1,
#   'Some': 5,
#   'tightly': 15,
#   'harshly': 5,
#   'Heavily': 1,
#   'aft': 3,
#   'dismally': 2,
#   'coolly': 5,
#   'Acourse': 1,
#   'airily': 2,
#   'O.K.': 1,
#   'nowadays': 8,
#   'thoughtfully': 10,
#   'How': 171,
#   'fitfully': 1,
#   'dimensionally': 1,
#   'plain-out': 1,
#   'exhaustively': 1,
#   'Inside': 7,
#   'since': 27,
#   'honorably': 2,
#   'wherewith': 1,
#   'upwards': 5,
#   'half-off': 1,
#   'discreetly': 1,
#   'fore': 1,
#   'decisively': 3,
#   'discordantly': 1,
#   'Once': 41,
#   'solemnly': 6,
#   'Privately': 2,
#   'formerly': 26,
#   'analytically': 1,
#   'spectrally': 1,
#   'nighttime': 1,
#   'blissfully': 1,
#   'A.D.': 8,
#   'unmistakably': 3,
#   'obviously': 67,
#   'flatteringly': 1,
#   'strenuously': 1,
#   'presumably': 28,
#   'improperly': 2,
#   'excellently': 4,
#   'humiliatingly': 1,
#   'abjectly': 1,
#   'intensively': 1,
#   'behind': 20,
#   'never': 549,
#   'morosely': 1,
#   'locally': 10,
#   'well': 551,
#   'grevouselye': 1,
#   'Together': 7,
#   'single-handedly': 2,
#   'Hence': 23,
#   'Thereafter': 3,
#   'nightly': 1,
#   'little': 91,
#   'convincingly': 1,
#   'Next': 10,
#   'Otherwise': 13,
#   'there': 425,
#   'Formally': 1,
#   'rollickingly': 1,
#   'offensively': 1,
#   'Wisely': 1,
#   'aloft': 2,
#   'ago': 196,
#   'ideally': 4,
#   'intently': 4,
#   'gladly': 1,
#   'not': 3562,
#   'indoors': 5,
#   'stern-to': 1,
#   'assuredly': 1,
#   'Back': 10,
#   'thereupon': 2,
#   'reflexly': 2,
#   'quantitatively': 1,
#   'scrupulously': 1,
#   'wher': 1,
#   'Specifically': 1,
#   'When': 460,
#   'proportionately': 6,
#   'friendlily': 1,
#   'incessantly': 2,
#   'kinda': 4,
#   'smoothly': 9,
#   'fussily': 1,
#   'simply': 140,
#   'anyway': 33,
#   'continuously': 19,
#   'grandly': 1,
#   "'round": 2,
#   'Second': 6,
#   'insidiously': 2,
#   'Presumably': 5,
#   'prophetically': 2,
#   'Already': 15,
#   'perpendicularly': 1,
#   'furthermore': 2,
#   'part-time': 1,
#   'residentially': 1,
#   'functionally': 2,
#   "more'n": 1,
#   'extremely': 41,
#   'Badly': 1,
#   'ominously': 3,
#   'daintily': 1,
#   'operationally': 1,
#   'Quietly': 1,
#   'loose': 7,
#   'nearby': 18,
#   'presently': 20,
#   'poetically': 1,
#   'instantaneously': 1,
#   'steamily': 1,
#   'possibly': 43,
#   'also': 793,
#   'Also': 57,
#   'agilely': 1,
#   'fatally': 3,
#   'Aw': 1,
#   'disturbingly': 1,
#   'broadly': 5,
#   'experimentally': 6,
#   'always': 353,
#   'painstakingly': 1,
#   'asymptotically': 1,
#   'inherently': 1,
#   'Futhermore': 1,
#   'aloof': 2,
#   'hither': 1,
#   'easy': 9,
#   'cheerfully': 5,
#   'pervasively': 1,
#   'horrifyingly': 1,
#   'seldom': 27,
#   'either': 23,
#   'sociologically': 1,
#   'dominantly': 1,
#   'backstage': 1,
#   'Hastily': 1,
#   'politely': 9,
#   'easier': 6,
#   'Thirdly': 1,
#   'undoubtedly': 13,
#   'unbearably': 1,
#   'concurrently': 1,
#   'a.m.': 19,
#   'poorly': 8,
#   'Happily': 1,
#   'wherein': 3,
#   'amply': 4,
#   'mercilessly': 3,
#   'Fourth': 1,
#   'heavier': 1,
#   'neither': 6,
#   'Unhappily': 1,
#   'terribly': 14,
#   'vocally': 1,
#   'shortly': 18,
#   'haughtily': 1,
#   'indirectly': 12,
#   'awful': 3,
#   'Technically': 1,
#   'foremost': 6,
#   'Normally': 2,
#   'paradoxically': 7,
#   'unceasingly': 1,
#   'Personally': 4,
#   'last': 24,
#   'effortlessly': 1,
#   'adversely': 2,
#   'incomparably': 3,
#   'oddly': 6,
#   'waspishly': 1,
#   'perchance': 1,
#   'administratively': 1,
#   'higher': 13,
#   'yonder': 1,
#   'conventionally': 1,
#   'rider-fashion': 1,
#   'distastefully': 2,
#   'academically': 5,
#   'monthly': 3,
#   'stealthily': 1,
#   'indelibly': 1,
#   'noisily': 3,
#   'comprehensively': 2,
#   'exultantly': 1,
#   'Aside': 6,
#   'ablaze': 3,
#   'Besides': 20,
#   'jealously': 1,
#   'unambiguously': 2,
#   'negatively': 2,
#   'implicitly': 3,
#   'Late': 1,
#   'immensely': 6,
#   'timidly': 1,
#   'Nonetheless': 3,
#   'deep': 12,
#   'brokenly': 1,
#   'gorgeously': 1,
#   'Analogously': 1,
#   'head-and-shoulders': 1,
#   'credibly': 1,
#   'adrift': 1,
#   'brilliantly': 7,
#   'Affirmatively': 1,
#   'asleep': 17,
#   'hand-in-glove': 1,
#   'Directly': 3,
#   'haltingly': 2,
#   'kindly': 3,
#   'glibly': 3,
#   'purely': 24,
#   'valiantly': 1,
#   'miserably': 3,
#   'temptingly': 1,
#   'stark': 1,
#   'That': 1,
#   'rather': 194,
#   'now': 823,
#   'Indirectly': 1,
#   'Sleepily': 1,
#   'inexorably': 1,
#   'grossly': 3,
#   'daily': 40,
#   'unilaterally': 1,
#   'easily': 83,
#   'astray': 2,
#   'Apprehensively': 1,
#   'perhaps': 171,
#   'above': 69,
#   'artfully': 3,
#   'uncritically': 1,
#   'adamantly': 1,
#   'absolutely': 21,
#   'prudentially': 1,
#   'Nevertheless': 35,
#   'uneasily': 5,
#   'slant-wise': 1,
#   'steeply': 1,
#   'within': 8,
#   'e.g.': 23,
#   'unquestionably': 6,
#   'tremulously': 1,
#   'Logically': 1,
#   'cold-bloodedly': 1,
#   'governmentally': 1,
#   'daytime': 1,
#   'Gradually': 6,
#   'hard': 48,
#   'Moreover': 55,
#   'Afterward': 1,
#   'analogously': 1,
#   'very': 543,
#   'druther': 1,
#   'Seemingly': 1,
#   'plainly': 16,
#   'alertly': 1,
#   'to-and-fro': 1,
#   'afoot': 1,
#   'fruitfully': 1,
#   'no': 163,
#   'ably': 2,
#   'unhurriedly': 2,
#   'auspiciously': 1,
#   'Generally': 12,
#   'mistakenly': 3,
#   'vividly': 7,
#   'Anatomically': 1,
#   'Occasionally': 14,
#   'magically': 3,
#   'soft': 1,
#   'Historically': 4,
#   'Somewhere': 10,
#   'solely': 18,
#   'smart': 1,
#   'awake': 7,
#   'low': 11,
#   'visibly': 5,
#   'stolidly': 2,
#   'beneath': 2,
#   'officially': 14,
#   'perfunctorily': 1,
#   'periodically': 5,
#   'Fine': 1,
#   'notably': 11,
#   'politically': 9,
#   'great': 11,
#   'then': 798,
#   'ingeniously': 1,
#   'uppermost': 1,
#   'Additionally': 1,
#   'afterwards': 6,
#   'apart': 39,
#   'limply': 1,
#   'By': 2,
#   'half-way': 3,
#   'enormously': 9,
#   'rebelliously': 3,
#   'bodily': 3,
#   'halfway': 8,
#   'mostly': 30,
#   'imperceptibly': 1,
#   'distractedly': 1,
#   'vastly': 7,
#   'atonally': 1,
#   'despairingly': 3,
#   'dramatically': 7,
#   'tearfully': 2,
#   'municipally': 1,
#   'warily': 2,
#   'yon': 1,
#   'elsewhere': 36,
#   'Instinctively': 2,
#   'psychologically': 2,
#   'Outside': 11,
#   'progressively': 5,
#   'rarely': 28,
#   'barely': 27,
#   'readily': 31,
#   'incoherently': 1,
#   'Yes': 69,
#   'routinely': 1,
#   'unpleasantly': 1,
#   'probably': 191,
#   'militantly': 1,
#   'plumb': 4,
#   'Throughout': 1,
#   'transversally': 1,
#   'hereabouts': 2,
#   'quarterly': 1,
#   'ironically': 3,
#   'heartily': 7,
#   'infinitesimally': 1,
#   'pleasantly': 9,
#   'Easily': 1,
#   'unreassuringly': 1,
#   'resourcefully': 1,
#   'ultimately': 13,
#   'unwittingly': 5,
#   'asunder': 1,
#   'traditionally': 8,
#   'Promptly': 3,
#   'Practically': 4,
#   'Immediately': 5,
#   'tensely': 3,
#   'admirably': 4,
#   'unsteadily': 1,
#   'Wildly': 1,
#   'impatiently': 6,
#   'absent-mindedly': 3,
#   'Momentarily': 1,
#   'Similarly': 14,
#   'uncertainly': 2,
#   'presentlye': 1,
#   'wittingly': 1,
#   'Presently': 8,
#   'ill': 2,
#   'imprecisely': 2,
#   'Therefore': 41,
#   'Automatically': 1,
#   'mockingly': 1,
#   'thick': 2,
#   'previously': 41,
#   'sensibly': 3,
#   'across': 8,
#   'dimly': 8,
#   'axially': 1,
#   'preferably': 8,
#   'stepwise': 2,
#   'Usually': 16,
#   'herewith': 2,
#   'longer': 105,
#   'separately': 9,
#   'plain': 2,
#   'worriedly': 1,
#   'medically': 2,
#   'awkwardly': 2,
#   'Musically': 1,
#   'authentically': 2,
#   'nonetheless': 5,
#   'eye-to-eye': 1,
#   'Anyway': 7,
#   'nimbly': 1,
#   'yea': 1,
#   'markedly': 3,
#   'midway': 4,
#   'peculiarly': 7,
#   'inward': 6,
#   'significantly': 9,
#   'Ahead': 3,
#   'mountainously': 1,
#   'reputedly': 3,
#   'cheaply': 2,
#   'Obviously': 22,
#   'thickly': 4,
#   'full': 8,
#   'imperiously': 2,
#   'gratis': 1,
#   'round': 12,
#   'actually': 95,
#   'Instantly': 1,
#   'transversely': 1,
#   'Publicly': 1,
#   'purportedly': 1,
#   'ca.': 2,
#   'crosswise': 1,
#   'individually': 14,
#   'directly': 109,
#   'subsequently': 8,
#   'flatly': 6,
#   'crossways': 1,
#   'false': 1,
#   'momentarily': 4,
#   'meticulously': 6,
#   'therefore': 125,
#   'Hardly': 6,
#   'inevitably': 27,
#   'Patiently': 1,
#   'Convulsively': 1,
#   'constantly': 31,
#   'Far': 10,
#   'involuntarily': 1,
#   'Obligingly': 1,
#   'alternatively': 2,
#   'Thence': 1,
#   'militarily': 2,
#   'reliably': 1,
#   'ther': 2,
#   'principally': 9,
#   'structurally': 2,
#   'reasonably': 26,
#   'some': 15,
#   'face-to-wall': 1,
#   'inescapably': 1,
#   'Particularly': 2,
#   'cracking': 1,
#   'firmly': 37,
#   'outright': 1,
#   'afterward': 13,
#   'linguistically': 1,
#   'Staggeringly': 1,
#   'Here': 108,
#   'shoulder-to-shoulder': 1,
#   'There': 33,
#   'Suddenly': 19,
#   'out': 1,
#   'stirringly': 1,
#   'justly': 5,
#   'Especially': 4,
#   'duly': 9,
#   'dourly': 1,
#   'allegedly': 2,
#   'deliberately': 24,
#   'satisfactorily': 9,
#   'askew': 1,
#   'skeptically': 1,
#   'instantly': 14,
#   'self-consciously': 3,
#   'anciently': 1,
#   'Thereupon': 2,
#   'Reputedly': 1,
#   'good-humoredly': 1,
#   'sedulously': 1,
#   'soon': 139,
#   'unexpectedly': 10,
#   "O'Clock": 2,
#   'strictly': 29,
#   'alone': 163,
#   'clairaudiently': 1,
#   'alreadeh': 1,
#   'unsuccessfully': 1,
#   'wrong': 3,
#   'accusingly': 2,
#   'industrially': 1,
#   'whereon': 1,
#   'cleanly': 2,
#   'closer': 30,
#   'securely': 3,
#   'unwillingly': 1,
#   'heretofore': 6,
#   'historically': 6,
#   'stoutly': 1,
#   'outboard': 1,
#   'lewdly': 1,
#   'slower': 2,
#   'publically': 1,
#   'brutally': 2,
#   'surreptitiously': 3,
#   'Nowadays': 1,
#   'Nae': 1,
#   'substantially': 24,
#   'thereon': 1,
#   'otherwise': 51,
#   'less': 162,
#   'devotedly': 1,
#   'unequally': 1,
#   'semantically': 2,
#   'so': 1084,
#   'ultrasonically': 1,
#   'initially': 12,
#   'Almost': 23,
#   'straightaway': 1,
#   'somehow': 50,
#   'minutely': 1,
#   'aggressively': 2,
#   'ruefully': 3,
#   'supinely': 1,
#   'soberly': 2,
#   'Thus': 136,
#   'Oddly': 3,
#   'out-of-doors': 1,
#   'haggardly': 1,
#   'square': 1,
#   'feverishly': 1,
#   'Lastly': 1,
#   'Bluntly': 1,
#   'True': 7,
#   'Not': 155,
#   'away': 360,
#   'sometimes': 132,
#   'uninterruptedly': 1,
#   'willy-nilly': 4,
#   'necessarily': 43,
#   'nominally': 3,
#   'Initially': 4,
#   'laughingly': 1,
#   'Previously': 2,
#   'irrevocably': 2,
#   'twice': 52,
#   'scholastically': 1,
#   'tremendously': 9,
#   'Better': 6,
#   'efficiently': 8,
#   ...},
#  'CONJ': {'&': 138,
#   "'n'": 2,
#   'An': 1,
#   "An'": 1,
#   'And': 770,
#   'But': 1105,
#   'Either': 6,
#   'Neither': 18,
#   'Nor': 28,
#   'Or': 72,
#   'Plus': 1,
#   'Yet': 57,
#   'an': 10,
#   "an'": 5,
#   'and': 22369,
#   'and/or': 14,
#   'but': 2301,
#   'butt': 2,
#   'either': 135,
#   'minus': 2,
#   'neither': 66,
#   'nor': 127,
#   'or': 3218,
#   'plus': 44,
#   'yet': 45},
#  'DET': {"'nother": 1,
#   'A': 953,
#   'An': 152,
#   'Another': 89,
#   'Any': 31,
#   'Both': 75,
#   'Each': 93,
#   'Either': 3,
#   'Every': 44,
#   'Her': 119,
#   'His': 423,
#   'Its': 59,
#   'My': 122,
#   'Neither': 10,
#   'No': 187,
#   'Our': 86,
#   'Some': 165,
#   'That': 226,
#   'The': 5807,
#   'Their': 97,
#   'Them': 2,
#   'These': 259,
#   'This': 924,
#   'Those': 60,
#   'Thy': 5,
#   'What': 369,
#   'Whatever': 20,
#   'Which': 17,
#   'Whichever': 1,
#   'Whose': 1,
#   'Whosever': 1,
#   "Y'r": 1,
#   'Ye': 1,
#   'Your': 40,
#   'a': 17377,
#   'an': 2848,
#   'ani': 2,
#   'another': 445,
#   "another's": 5,
#   'any': 1025,
#   'anye': 1,
#   'both': 536,
#   'each': 603,
#   'either': 51,
#   "ever'": 1,
#   'every': 334,
#   'her': 1459,
#   'his': 5146,
#   'hys': 5,
#   'its': 1431,
#   'mah': 2,
#   'mine': 1,
#   'my': 951,
#   'myne': 1,
#   'neither': 12,
#   'nether': 1,
#   'no': 1250,
#   'one': 2,
#   'our': 885,
#   'out': 1,
#   'some': 1135,
#   "th'": 1,
#   'that': 1607,
#   'the': 50287,
#   'thees': 1,
#   'their': 2057,
#   'them': 6,
#   'ther': 2,
#   'these': 984,
#   'thet': 1,
#   'thine': 1,
#   'this': 3203,
#   'those': 623,
#   'thy': 5,
#   'what': 1132,
#   'whatever': 73,
#   'which': 2844,
#   'whichever': 4,
#   'whichever-the-hell': 1,
#   'whose': 200,
#   'yore': 1,
#   'your': 685},
#  'NOUN': {'decks': 5,
#   'willingness': 9,
#   'fine': 6,
#   'firmness': 3,
#   'eggs': 26,
#   'Albanians': 2,
#   'AAA': 1,
#   'Davenport': 2,
#   'mummies': 1,
#   'pit': 10,
#   'self-satisfaction': 3,
#   "Cibula's": 1,
#   'illusion': 28,
#   'commencement': 3,
#   'gourmet': 1,
#   'Packard': 10,
#   'mezzo': 1,
#   'madmen': 3,
#   'un': 1,
#   'Organification': 1,
#   'Poems': 5,
#   'telephone': 51,
#   'psychiatrist': 4,
#   'Siberia': 5,
#   'Doris': 5,
#   'Sagami': 1,
#   'B-52s': 1,
#   'no.': 7,
#   'Sea-road': 1,
#   'Remy': 1,
#   'credits': 4,
#   'yarns': 4,
#   '$20,000,000': 1,
#   'Grenier': 2,
#   'exacerbation': 3,
#   'howls': 1,
#   '$8,250': 1,
#   "Berger's": 4,
#   'Celie': 1,
#   'Rumor': 4,
#   'boards': 34,
#   'Micawber': 1,
#   'Fruit': 3,
#   'Lander': 1,
#   'crickets': 2,
#   'washbasin': 1,
#   'Schoolmarm': 1,
#   'sinner': 3,
#   'Atlantica': 1,
#   'retainers': 1,
#   'underclassman': 1,
#   'equal': 1,
#   'firearms': 3,
#   'neo-dadaist': 1,
#   '$0.9': 1,
#   'Conant': 5,
#   'ministrations': 2,
#   'Lilian': 6,
#   'Cox': 3,
#   'Owen': 21,
#   'cigarette': 18,
#   '$2,000': 3,
#   'pads': 4,
#   '$3,500,000': 2,
#   'pupil': 18,
#   'creations': 2,
#   "Marcel's": 1,
#   'Sponsor': 5,
#   'sequence': 29,
#   'Plainfield': 2,
#   'Sangallo': 1,
#   'Railway': 2,
#   'Cahill': 1,
#   'modernism': 1,
#   "Round's": 1,
#   'intensities': 3,
#   'battery': 13,
#   "McSorley's": 1,
#   'Mephistopheles': 1,
#   'entertainers': 3,
#   'countenance': 6,
#   'Pipgras': 1,
#   'standby': 2,
#   'cluck': 1,
#   "Berlin's": 4,
#   'Boeing': 3,
#   'innocents': 1,
#   'Crowds': 2,
#   'outpatient': 1,
#   'deadlines': 1,
#   'Mobilization': 2,
#   'free-world': 1,
#   'residue': 7,
#   'skins': 5,
#   'openings': 6,
#   'Strikes': 2,
#   'peptide': 1,
#   'Brownlow': 1,
#   'pair': 38,
#   'Emilio': 1,
#   'cornmeal': 1,
#   'bellboys': 1,
#   "1/2''": 6,
#   'Philosophies': 1,
#   'Sullivan': 6,
#   'endogamy': 2,
#   'survivalist': 1,
#   'Orinoco': 1,
#   'Fujimoto': 2,
#   "Bancroft's": 1,
#   'Kool-Aid': 1,
#   'Mack': 1,
#   'Insinuations': 1,
#   'jig': 5,
#   'Huddle': 1,
#   'Sigmund': 1,
#   'shell-psychology': 1,
#   'rat': 6,
#   'Pezza': 3,
#   'instillation': 1,
#   'Selena': 4,
#   'Artkino': 1,
#   'persistence': 7,
#   'Angelina': 4,
#   'escapist': 1,
#   'Aspencade': 1,
#   'embassies': 5,
#   'Astarte': 1,
#   'Long-term': 1,
#   'Andy': 27,
#   'substitution': 2,
#   '463-degrees-C': 1,
#   'figures': 69,
#   'headboard': 1,
#   'Venn': 1,
#   'Karamazov': 3,
#   'Cook': 18,
#   'phosphors': 1,
#   'aviator': 3,
#   'Cherokee': 1,
#   'greenhouses': 1,
#   'Pi': 2,
#   'Basketball': 1,
#   'Vienot': 1,
#   'taxis': 2,
#   'weeks': 111,
#   'coroner': 4,
#   'bayleefe': 1,
#   'Budweisers': 1,
#   'comma': 1,
#   'credo': 7,
#   'jumps': 1,
#   'gavottes': 1,
#   'avail': 1,
#   'Rostagnos': 1,
#   'improvisations': 2,
#   'athletes': 5,
#   'wilderness': 8,
#   'incorporation': 3,
#   'tabloids': 1,
#   'Nashville': 7,
#   't-tau': 1,
#   'Fitch': 1,
#   'paragon': 1,
#   'Poitrine': 3,
#   'tellers': 2,
#   'interlining': 1,
#   'Alabama': 18,
#   'inventories': 9,
#   'tsunami': 17,
#   'elder': 1,
#   'ears': 27,
#   'Jersey': 19,
#   'tutorials': 1,
#   'polyisocyanates': 1,
#   'Kittler': 1,
#   'fairs': 1,
#   'mischief': 5,
#   'peacock': 2,
#   'contrast': 57,
#   'ignoramus': 2,
#   'resins': 2,
#   'brachii': 1,
#   'Gar-Dene': 2,
#   'author': 31,
#   'Jokes': 1,
#   'Playboy-Show-Biz': 1,
#   'touchdowns': 1,
#   'choreography': 3,
#   'absorbency': 1,
#   'horde': 2,
#   'Interest': 5,
#   'Decay': 1,
#   'imperfections': 2,
#   'happening': 2,
#   'Holmes': 30,
#   'Beiderbecke': 1,
#   'Meditations': 2,
#   'Scene': 4,
#   'self-crimination': 1,
#   'rhythms': 8,
#   'Fate': 3,
#   'chocolate': 7,
#   '$500': 10,
#   'Prattville': 1,
#   'Amendments': 3,
#   'goals': 24,
#   'Bourbons': 3,
#   'Infantry': 3,
#   'Temper': 1,
#   'textiles': 9,
#   'slum': 6,
#   'tar': 2,
#   'Prejudice': 1,
#   'sinners': 2,
#   'Hump': 2,
#   'rivalry': 6,
#   'epoxy': 2,
#   'Carolina': 20,
#   'panel': 22,
#   'cruises': 1,
#   'Bank': 23,
#   'grudge': 5,
#   'lemon': 9,
#   'Maser': 1,
#   'impact': 50,
#   'Ry.': 1,
#   'confusions': 2,
#   'paratroopers': 1,
#   'tree-clumps': 2,
#   'Zinman': 1,
#   'Soviets': 9,
#   'Hartman': 3,
#   'Hardshell': 1,
#   'dealer': 19,
#   '21%': 1,
#   'agnomen': 1,
#   'volcanos': 1,
#   'Anything': 13,
#   'Doubts': 1,
#   'halt': 3,
#   'achievements': 17,
#   'hoofs': 5,
#   'anything': 215,
#   'T': 60,
#   'exuberance': 1,
#   'affectation': 1,
#   "war's": 1,
#   'savagery': 1,
#   "Chicago's": 7,
#   'nobility': 3,
#   'deficiencies': 10,
#   'Sherlock': 4,
#   'Medea': 1,
#   'Estimate': 3,
#   'Louisville': 5,
#   "Braves'": 1,
#   'pseudo-willing': 1,
#   'gullies': 1,
#   "Dwyer's": 1,
#   'prodigy': 3,
#   'Morse': 24,
#   '$300': 6,
#   'slug': 7,
#   'smokehouse': 2,
#   'vividness': 1,
#   'secretary-treasurer': 2,
#   "N.C.'s": 1,
#   'baseballs': 1,
#   'Clements': 3,
#   'Tire': 2,
#   'accusation': 3,
#   'personalities': 11,
#   'irregulars': 1,
#   'Beebe': 2,
#   'housebreaking': 1,
#   'mudwagon': 1,
#   'mysticisms': 1,
#   'suck': 1,
#   'germ': 2,
#   'Lauderdale': 4,
#   'pulsations': 1,
#   'Lohmans': 1,
#   'sweepstakes': 1,
#   'Crossman': 1,
#   'preaching': 6,
#   'successors': 6,
#   'competence': 13,
#   'train': 56,
#   'pathways': 2,
#   'Nazism': 1,
#   'salons': 2,
#   "Adam's": 2,
#   'Mercers': 1,
#   'Sarpsis': 2,
#   'caraway': 2,
#   'interviewer': 2,
#   'Stickler': 1,
#   'super-experiment': 1,
#   "manufacturers'": 2,
#   'Sumatra': 1,
#   'ground-truck': 1,
#   'Derby': 3,
#   'games': 42,
#   'strait': 3,
#   'intellectuals': 10,
#   'Cereal': 3,
#   'Benediction': 1,
#   'verses': 8,
#   'stapling': 1,
#   'Komleva': 1,
#   'Wound-tumor': 1,
#   'capabilities': 15,
#   'executive': 28,
#   'fielder': 2,
#   'transaminase': 1,
#   'Capet': 2,
#   'Sophia': 3,
#   'confessionals': 1,
#   'structure': 73,
#   'Englishman': 13,
#   'I.Q.': 5,
#   'vinegar': 8,
#   'Beauchamps': 1,
#   '58.8%': 1,
#   'suavity': 1,
#   'System': 16,
#   'males': 14,
#   'Leyte': 4,
#   'sambur': 1,
#   'Lippmann': 1,
#   'shelves': 7,
#   'observations': 28,
#   'appearances': 13,
#   'Hunters': 1,
#   'reluctance': 5,
#   'gladness': 1,
#   'critique': 1,
#   'Huntingtons': 1,
#   'balustrade': 3,
#   'shovels': 3,
#   'Scotch': 1,
#   'Realtors': 4,
#   'Morals': 1,
#   'Source': 2,
#   'Barrel': 1,
#   'receipts': 5,
#   'Pauson': 2,
#   'paramagnet': 1,
#   'cockroaches': 1,
#   "Calhoun's": 1,
#   'noises': 4,
#   'flutter': 2,
#   'groove': 1,
#   'eruption': 2,
#   'Angola': 3,
#   'social-welfare': 1,
#   'Taylors': 1,
#   "guide's": 1,
#   "Prentice's": 1,
#   'gradualist': 1,
#   'filigree': 1,
#   'stockynges': 1,
#   'spring-training': 1,
#   'keynotes': 1,
#   'fools': 3,
# ...
#   'cost': 37,
#   'combating': 1,
#   'hire': 14,
#   'lopped': 1,
#   'absented': 1,
#   'transplanting': 1,
#   'Planning': 9,
#   'shaded': 6,
#   'erupts': 1,
#   'Blowing': 1,
#   'ruptured': 2,
#   'filling': 21,
#   'structuring': 1,
#   'unravel': 1,
#   'align': 2,
#   'roughed': 1,
#   'haranguing': 2,
#   'supporting': 24,
#   'Talk': 3,
#   'pontificates': 1,
#   'Blistered': 1,
#   'cradled': 2,
#   'had': 4106,
#   'fasten': 4,
#   'shelter': 1,
#   'categorize': 1,
#   'fairing': 1,
#   'blankets': 1,
#   'frowns': 1,
#   'bumped': 2,
#   'allowed': 66,
#   'Faces': 1,
#   'humped': 1,
#   'blunted': 1,
#   'gleaned': 1,
#   'complimented': 2,
#   'expend': 1,
#   'slowed': 12,
#   'crocked': 1,
#   'revolutionized': 3,
#   'presided': 1,
#   'pluck': 1,
#   'complains': 3,
#   'guarantees': 4,
#   'delight': 2,
#   'ached': 3,
#   'imperiled': 1,
#   'incur': 4,
#   'inferred': 3,
#   'repeat': 16,
#   'lionized': 1,
#   'hampered': 3,
#   'amending': 1,
#   'should': 694,
#   'mother': 1,
#   'linked': 9,
#   'unthaw': 1,
#   'mutters': 1,
#   'behold': 2,
#   'wrings': 1,
#   'Vending': 1,
#   'exonerated': 1,
#   'sifted': 3,
#   'ramble': 1,
#   'touring': 3,
#   'enlists': 1,
#   'apply': 47,
#   'differentiated': 4,
#   'executed': 11,
#   'felt': 298,
#   'elicits': 1,
#   'Slow': 1,
#   'darkening': 4,
#   'partaking': 1,
#   'deployed': 3,
#   'consoling': 1,
#   'sprouting': 3,
#   'suspect': 16,
#   'baffle': 1,
#   'skirted': 1,
#   'ranged': 15,
#   'delivre': 1,
#   'prevented': 22,
#   'rides': 4,
#   'glowing': 10,
#   'ailing': 2,
#   'last': 19,
#   'wobbled': 1,
#   'striking': 9,
#   'misleads': 1,
#   'detribalize': 1,
#   'stereotyped': 4,
#   'Hear': 1,
#   'pouted': 1,
#   'sickened': 3,
#   'paled': 1,
#   'chanting': 1,
#   'perplex': 1,
#   'threatening': 19,
#   'surpass': 1,
#   'adheres': 1,
#   'shrank': 1,
#   'patented': 3,
#   'stalling': 1,
#   'shocks': 1,
#   'unfolds': 3,
#   'dump': 2,
#   'scoring': 4,
#   'appraise': 3,
#   'roaming': 3,
#   'respond': 14,
#   'unlinked': 1,
#   'casting': 2,
#   'featured': 7,
#   'rinse': 1,
#   'desire': 6,
#   'crucifying': 2,
#   'unsealed': 1,
#   'elicit': 2,
#   'differs': 7,
#   'mediating': 1,
#   'fuels': 1,
#   'file': 24,
#   'sugared': 1,
#   'puff': 1,
#   'preparing': 16,
#   'snubbing': 1,
#   'conserve': 2,
#   'Restudy': 1,
#   'became': 198,
#   'integrate': 7,
#   'Proves': 1,
#   'presents': 22,
#   'endorsing': 1,
#   'embezzle': 1,
#   'deadened': 1,
#   'evaporated': 2,
#   'services': 1,
#   'override': 1,
#   'regarding': 1,
#   'budgeted': 2,
#   'minifying': 1,
#   'glanced': 18,
#   'overhaul': 1,
#   'spiraling': 1,
#   'Freed': 2,
#   'quarrels': 1,
#   'predetermined': 3,
#   'encased': 1,
#   'distil': 1,
#   'pump': 1,
#   'chauffeured': 1,
#   'skouting': 1,
#   'Hatching': 1,
#   'pool': 2,
#   'recollect': 1,
#   'surrender': 6,
#   'content': 2,
#   'Leasing': 1,
#   'induces': 1,
#   'spotlights': 1,
#   'necessitate': 4,
#   'harnessed': 2,
#   'taken': 224,
#   'coupled': 10,
#   'characterize': 5,
#   'Published': 4,
#   'sculptured': 4,
#   'hyphenated': 1,
#   'Line': 1,
#   'taunted': 1,
#   'incepting': 3,
#   'outspread': 1,
#   'hevin': 2,
#   'acculturated': 1,
#   'Touring': 2,
#   'distilled': 7,
#   'jerked': 7,
#   'toppled': 2,
#   'feigned': 1,
#   'Refill': 1,
#   'overwhelmed': 3,
#   'lapse': 2,
#   'acclaims': 1,
#   'outdo': 1,
#   'plots': 1,
#   'potted': 2,
#   'stock': 2,
#   'jump': 14,
#   'gotta': 4,
#   'wet': 6,
#   'drifts': 1,
#   'vibrating': 1,
#   'whirring': 2,
#   'experience': 16,
#   'Dealing': 1,
#   'tossing': 3,
#   'drank': 18,
#   'Seems': 5,
#   'terrifying': 4,
#   'Forked': 1,
#   'hand-filed': 1,
#   'ache': 1,
#   'glossed': 1,
#   'sidle': 1,
#   'ignoring': 4,
#   'burrowing': 1,
#   'Prevents': 1,
#   'share': 31,
#   'exemplifies': 1,
#   'pace': 4,
#   'Expresses': 1,
#   'cultivated': 7,
#   'catapulted': 2,
#   'sorted': 4,
#   'coping': 5,
#   'wishes': 11,
#   'categorizing': 1,
#   'obtaining': 5,
#   'strikes': 8,
#   'Place': 17,
#   'risking': 1,
#   'pillaged': 1,
#   'prescribed': 11,
#   'proposing': 3,
#   'order': 12,
#   'Retracing': 1,
#   'reassign': 1,
#   'punch': 1,
#   'vexed': 2,
#   'extending': 20,
#   'marking': 9,
#   'single-foot': 1,
#   'tagged': 6,
#   'saddled': 4,
#   'crowed': 2,
#   'speaking': 37,
#   'Figure': 1,
#   'generalized': 7,
#   'rebels': 1,
#   'lacquered': 1,
#   'Concluding': 1,
#   'beckons': 2,
#   'accuses': 1,
#   "haven't": 28,
#   'Taking': 10,
#   'clatter': 1,
#   'discriminate': 1,
#   'strengthening': 7,
#   'stick': 12,
#   'pricing': 5,
#   'presupposes': 2,
#   'Anticipated': 1,
#   'legitimized': 2,
#   'outgrip': 1,
#   'fulfills': 2,
#   'fussing': 2,
#   'intimating': 1,
#   'dot': 2,
#   'inched': 1,
#   'braided': 1,
#   'Drill': 7,
#   'poke': 1,
#   'potting': 1,
#   'transposed': 4,
#   'taught': 39,
#   'incensed': 3,
#   'exceeds': 8,
#   'decry': 1,
#   'flanked': 4,
#   'defining': 6,
#   "shootin'": 1,
#   'dropped': 78,
#   'amortize': 2,
#   'acquires': 1,
#   'Supporting': 2,
#   'fashions': 1,
#   'unlock': 1,
#   'deteriorate': 1,
#   'utilized': 10,
#   'grumbling': 1,
#   'mining': 6,
#   'insure': 16,
#   'burdened': 3,
#   'fluttering': 2,
#   'cheating': 1,
#   'vibrated': 1,
#   'improves': 8,
#   'tortures': 1,
#   'rejoices': 1,
#   'people': 1,
#   'stomped': 2,
#   'Molding': 1,
#   'perforated': 1,
#   'basked': 1,
#   'cancel': 5,
#   ...},
#  'X': {'(': 9,
#   ')': 9,
#   ',': 1,
#   '-': 5,
#   '--': 1,
#   '135*0C.': 1,
#   '29': 1,
#   '32*0C.': 1,
#   '32-degrees-C': 1,
#   '38': 3,
#   '38*0': 1,
#   '43*0': 1,
#   '43*0C': 1,
#   '43*0C.': 1,
#   '49*0': 1,
#   '60*0C.': 1,
#   '71*&0C.': 1,
#   '?': 1,
#   'A': 1,
#   'ASPIS': 1,
#   'Adios': 1,
#   'Af': 1,
#   'Affaires': 1,
#   'Afrika': 1,
#   'Afrique': 1,
#   'Al': 1,
#   'Allons': 1,
#   'Alors': 1,
#   'Alsatian': 1,
#   'Amici': 1,
#   'Amt': 1,
#   'Angleterre': 1,
#   'Angst': 2,
#   'Arc': 1,
#   'Arigato': 1,
#   'Arte': 4,
#   'Artisans': 1,
#   'Auf': 1,
#   'B.t.u./sq.': 1,
#   'Ballet': 2,
#   'Bas': 1,
#   'Bayerische': 1,
#   'Belge': 1,
#   'Bestimmung': 1,
#   'Bon': 2,
#   'Bonjour': 1,
#   'Bremsstrahlung': 1,
#   'Britannica': 1,
#   'Buber-think': 1,
#   'Buenas': 1,
#   'Bueno': 1,
#   'Bureau': 1,
#   "C'est": 1,
#   'C.': 1,
#   'Calimala': 1,
#   'Capello': 1,
#   'Carrozza': 1,
#   'Carthago': 1,
#   'Cavaliere': 1,
#   'Centrale': 1,
#   'Chambre': 1,
#   'Champs': 1,
#   'Chemische': 3,
#   'Chili': 1,
#   'Ciao': 1,
#   'Cieca': 1,
#   'Comedie': 12,
#   'Comique': 1,
#   'Commercants': 1,
#   'Compagnie': 1,
#   'Concertante': 1,
#   'Concerts': 1,
#   'Concorde': 1,
#   'Conquete': 1,
#   'Conseil': 2,
#   'Crisis': 1,
#   'Crus': 3,
#   'Curiae': 1,
#   "D'Argent": 1,
#   'Dachshund': 1,
#   'Das': 1,
#   'De': 18,
#   'Dei': 1,
#   'Della': 2,
#   'Democratique': 1,
#   'Demographie': 1,
#   'Des': 4,
#   'Deus': 1,
#   'Deutsche': 1,
#   'Die': 4,
#   'Dieu': 1,
#   'Dieux': 1,
#   'Direction': 1,
#   'Dolce': 5,
#   'Domina': 2,
#   'Douce': 1,
#   'Du': 4,
#   'Dummkopf': 1,
#   'Dunkirk': 1,
#   'EUMMELIHS': 1,
#   'Ecole': 1,
#   'Einsatzkommandos': 1,
#   'El': 2,
#   'Eliot-or-Martin': 1,
#   'En': 2,
#   'Engages': 1,
#   'Erde': 1,
#   'Escadrille': 1,
#   'Espagnol': 1,
#   'Espanol': 1,
#   'Femmes': 1,
#   'Fermate': 1,
#   'Fil': 1,
#   'Fledermaus': 1,
#   'Force': 2,
#   'Forces': 2,
#   'Forellen': 1,
#   'Francaise': 2,
#   'Frist': 1,
#   'Gauleiter': 1,
#   'Gemeinschaft': 1,
#   'Generale': 3,
#   'Gesamtkunstwerke': 1,
#   'Gladius': 1,
#   'Gott': 1,
#   'Gouvernement': 1,
#   'Gracias': 2,
#   'Grammophon': 1,
#   'Grand': 1,
#   'Grands': 3,
#   'Habla': 1,
#   'Hexen': 1,
#   'Homo': 1,
#   'Hovdingar': 1,
#   'Hoy': 1,
#   'Ich': 1,
#   'Idea': 1,
#   'Il': 2,
#   'Indigenes': 1,
#   'Industrialistes': 1,
#   'Inferno': 1,
#   'Institut': 1,
#   'Internationale': 1,
#   'Invictus': 1,
#   "J'ai": 1,
#   'Jahr': 1,
#   'Jardin': 1,
#   'Jour': 2,
#   'Karshilama': 1,
#   'Klinico': 1,
#   'Konzerthaus': 1,
#   'Kristallstrukturen': 1,
#   'Krystallographie': 3,
#   'Kulturbund': 4,
#   "L'Arcade": 1,
#   "L'Astree": 1,
#   "L'Imperiale": 1,
#   "L'Institut": 1,
#   "L'Union": 2,
#   "L'Unita": 1,
#   "L'orchestre": 1,
#   'LD': 1,
#   'La': 21,
#   'Lana': 1,
#   'Las': 1,
#   'Le': 1,
#   'Les': 1,
#   'Liber': 1,
#   'Lumiere': 1,
#   'Lutte': 1,
#   'Mademoiselle': 1,
#   "Main-d'Oeuvre": 1,
#   'Marocaine': 1,
#   'Mater': 1,
#   'Medecine': 1,
#   'Meinung': 1,
#   'Metamorphose': 1,
#   'Mi': 1,
#   'Mio': 1,
#   'Missa': 1,
#   'Monde': 1,
#   'Mullerin': 1,
#   'Musee': 1,
#   'Musica': 1,
#   'Musicale': 1,
#   'Musique': 1,
#   'Nacht': 2,
#   'National': 1,
#   'Naturam': 1,
#   'Nichtige': 1,
#   'Non': 2,
#   'Notitia': 1,
#   'Nouvelle': 1,
#   'Nuit': 2,
#   'Nuovo': 1,
#   'O': 1,
#   'Officielle': 1,
#   'Orchester': 1,
#   'Orchestre': 1,
#   'Pacta': 1,
#   'Paix': 1,
#   'Paredon': 2,
#   'Parti': 1,
#   'Pas': 1,
#   'Pater': 1,
#   'Pati': 1,
#   'Pax': 1,
#   'Pendant': 1,
#   'Philharmonique': 1,
#   'Piazza': 2,
#   'Place': 5,
#   'Planeten': 1,
#   'Platonica': 1,
#   'Populaires': 1,
#   'Porto': 1,
#   'Prix': 1,
#   'Pro': 1,
#   'Publique': 2,
#   'Pueri': 1,
#   'Putas': 1,
#   'Puttana': 1,
#   'Qui': 1,
#   'Quintus': 2,
#   'Quod': 1,
#   'Rapport': 1,
#   'Recherche': 1,
#   'Recherches': 1,
#   'Redoute': 3,
#   'Reine': 1,
#   'Revolutionibus': 2,
#   'Ripa': 1,
#   'Romano': 1,
#   'Romanza': 1,
#   'Rondo': 1,
#   'Rue': 3,
#   'Rundfunk': 1,
#   'S.': 1,
#   'SAKOS': 1,
#   'Sabinas': 1,
#   'Sake': 2,
#   'Samba': 1,
#   'Sans': 1,
#   'Schone': 1,
#   'Schwarzen': 1,
#   'Scientifique': 1,
#   'Se': 1,
#   'Section': 1,
#   'Senium': 1,
#   'Serieuses': 1,
#   'Servanda': 1,
#   'Service': 1,
#   'Sextuor': 1,
#   'Sic': 1,
#   'Siciliana': 1,
#   'Sie': 1,
#   'Signora': 1,
#   'Sinfonica': 1,
#   'Soba': 1,
#   'Soiree': 1,
#   'Sole': 1,
#   'Solemnis': 1,
#   'Son': 1,
#   'Sonambula': 1,
#   'Spagna': 1,
#   'Stabat': 1,
#   'Stadtisches': 1,
#   'Statistique': 1,
#   'Statuto': 1,
#   'Strukturbericht': 1,
#   'Sultane': 1,
#   'Sur': 2,
#   'Sushi': 1,
#   'Svenskarna': 1,
#   'Systeme': 1,
#   'Tabellen': 1,
#   'Tanin': 1,
#   'Tchalo': 1,
#   'Telegraphie': 1,
#   'Tertre': 1,
#   'Then': 1,
#   'Thus': 1,
#   'Tory': 1,
#   'Toujours': 1,
#   'Tour': 2,
#   'Triomphe': 1,
#   'Variations': 1,
#   'Vergessen': 1,
#   'Via': 1,
#   'Viator': 1,
#   'Vita': 5,
#   'Volksgeist': 1,
#   'Von': 3,
#   'Vous': 2,
#   'Wanderjahr': 1,
#   'Weltanschauung': 1,
#   'Whaddya': 1,
#   'Y': 1,
#   'Zeitgeist': 1,
#   'Zur': 1,
#   'Zwei': 1,
#   'a': 5,
#   'aber': 1,
#   'about': 1,
#   'ad': 5,
#   'adieu': 1,
#   'age': 1,
#   'agricolas': 1,
#   'al': 5,
#   'al.': 1,
#   'alors': 1,
#   'alpha-beta-gammas': 1,
#   'amici': 2,
#   'amigo': 2,
#   'an': 1,
#   'and': 2,
#   'annee': 1,
#   'apartheid': 1,
#   'aquam': 1,
#   'as': 1,
#   'attack': 1,
#   'attis': 1,
#   'audivi': 1,
#   'auf': 1,
#   "aujourd'hui": 1,
#   'avant': 1,
#   'avec': 1,
#   'baci': 1,
#   'baklava': 1,
#   'ballet': 1,
#   'banditos': 1,
#   'basileis': 1,
#   'basso': 1,
#   'be': 2,
#   'before': 1,
#   'being': 1,
#   'bel': 3,
#   'bete': 1,
#   'bevor': 1,
#   'bianco': 1,
#   'bien': 1,
#   'bijouterie': 1,
#   'biwa': 6,
#   'blutwurst': 1,
#   'bockwurst': 1,
#   'bois': 1,
#   'boite': 1,
#   'boites': 1,
#   'bona': 1,
#   'bonheur': 1,
#   'bouanahsha': 1,
#   'bouffe': 1,
#   'boun': 1,
#   'bratwurst': 1,
#   'by': 1,
#   'calls': 1,
#   'can': 1,
#   'canto': 3,
#   'carne': 3,
#   'carob': 1,
#   'certain': 1,
#   'cetera': 4,
#   'ceteras': 1,
#   'chambre': 3,
#   "chambre's": 1,
#   'chantier': 1,
#   'chartaceos': 1,
#   'chelas': 1,
#   'chevaux': 1,
#   'chili': 2,
#   'chimiques': 1,
#   'chole': 1,
#   'cinq': 1,
#   'circonscription': 1,
#   'circonscriptions': 1,
#   'cocu': 1,
#   'comedie': 1,
#   'commence': 1,
#   'commitments': 1,
#   'con': 3,
#   'conquete': 1,
#   'construction': 1,
#   'contadini': 2,
#   'contendere': 1,
#   'continuo': 1,
#   'cordon': 1,
#   'corporis': 1,
#   'corps': 6,
#   'corpus': 1,
#   'corroborees': 2,
#   'coup': 1,
#   'coureurs': 1,
#   'crus': 1,
#   'cuisine': 1,
#   'culte': 1,
#   'curiae': 2,
#   "d'Eiffel": 1,
#   "d'art": 1,
#   "d'entretenir": 1,
#   "d'etat": 1,
#   "d'hotel": 1,
#   "d'identite": 1,
#   "d'un": 1,
#   "d'you": 1,
#   "dabhumaksanigalu'ahai": 1,
#   'dans': 1,
#   'das': 1,
#   'de': 38,
#   'def': 1,
#   'deja': 5,
#   'dejeuners': 1,
#   'del': 1,
#   'delenda': 1,
#   'delicti': 1,
#   'demographiques': 1,
#   'der': 1,
#   'deras': 1,
#   'des': 2,
#   'despues': 1,
#   'deux': 3,
#   'development': 1,
#   'di': 1,
#   'diapiace': 1,
#   'die': 3,
#   'difficile': 1,
#   'dites': 1,
#   'doble': 1,
#   'domi': 1,
#   'du': 2,
#   'duces': 1,
#   'ein': 2,
#   'eine': 1,
#   'electriques': 1,
#   'en': 3,
#   'enfant': 1,
#   'engages': 4,
#   'enquetes': 1,
#   'entered': 1,
#   'ersatz': 2,
#   'esprit': 5,
#   'esse': 2,
#   'est': 3,
#   'et': 21,
#   'etes': 1,
#   'even': 1,
#   'ex': 2,
#   'exceed': 1,
#   'excellence': 2,
#   'expenditures': 1,
#   'extremis': 1,
#   'facto': 6,
#   'faim': 1,
#   'faires': 1,
#   'femme': 1,
#   'festivus': 1,
#   'fide': 1,
#   'fille': 5,
#   'filles': 1,
#   'firma': 1,
#   'force': 1,
#   'forisque': 1,
#   'formidable': 1,
#   'frise': 1,
#   'ft.': 1,
#   'gai': 1,
#   'garde': 1,
#   'gegenschein': 1,
#   'ghazal': 1,
#   'given': 1,
#   'gosaimasu': 1,
#   'goutte': 1,
#   'grata': 1,
#   'habe': 1,
#   'haflis': 1,
#   'has': 1,
#   'haute': 2,
#   'he': 2,
#   'heute': 1,
#   'his': 2,
#   'hoc': 3,
#   'humaine': 1,
#   'if': 1,
#   'ij': 1,
#   'illusions': 1,
#   'in': 3,
#   'infinitum': 1,
#   'intellectus': 1,
#   'into': 2,
#   'intonaco': 2,
#   'ipso': 1,
#   'is': 1,
#   'ist': 1,
#   'je': 1,
#   'joie': 1,
#   'jour': 2,
#   'jure': 2,
#   'juste': 1,
#   'justitia': 1,
#   'keddah': 1,
#   'keine': 1,
#   'khaneh': 1,
#   'koan': 1,
#   'koinonia': 2,
#   'kolkhoz': 2,
#   'kolkhozes': 2,
#   'kotowaza': 1,
#   "ksu'u'peli'afo": 1,
#   'kwashiorkor': 1,
#   "l'Ange": 1,
#   "l'Independance": 1,
#   "l'Osservatore": 1,
#   "l'Universite": 1,
#   "l'activite": 1,
#   "l'identite": 1,
#   'la': 7,
#   'lacheln': 1,
#   'laendler': 1,
#   'lana': 1,
#   'lange': 1,
#   'launched': 1,
#   'launches': 1,
#   'le': 3,
#   'les': 1,
#   'lex': 1,
#   'libellos': 1,
#   'liste': 1,
#   'lutihaw': 1,
#   'ma': 1,
#   'made': 2,
#   "mai'teipa": 1,
#   'mais': 1,
#   'maitre': 1,
#   'maku': 2,
#   'mano': 2,
#   'maria': 1,
#   'mater': 1,
#   'material/hr./*0F./in.': 1,
#   'matinals': 1,
#   'matsyendra': 1,
#   'may': 1,
#   'me': 1,
#   'mea': 1,
#   'measuring': 1,
#   'mecum': 2,
#   'mem': 1,
#   'messieurs': 1,
#   'metier': 1,
#   'metis': 1,
#   'mettwurst': 1,
#   'milord': 2,
#   'minber': 1,
#   'ministers': 1,
#   'miso': 1,
#   'miuchi': 1,
#   'moi': 1,
#   'mon': 1,
#   'monde': 1,
#   'more': 1,
#   'morgen': 1,
#   'mot': 1,
#   'must': 1,
#   'ne': 1,
#   'negociant': 2,
#   'negociants': 1,
#   'ngandlu': 1,
#   'nisf-i-jahan': 1,
#   'noir': 1,
#   'noire': 1,
#   'nolens': 1,
#   'noli': 1,
#   'nolo': 1,
#   'non': 4,
#   'novo': 1,
#   'nuper': 1,
#   'objets': 1,
#   'obligations': 1,
#   'obliterans': 1,
#   'och': 1,
#   'of': 2,
#   'officio': 1,
#   'on': 2,
#   'opera': 1,
#   'optimo': 1,
#   'or': 1,
#   'ordinarius': 1,
#   'ordo': 3,
#   'ostinato': 1,
#   'oui': 1,
#   'oyabun': 4,
#   'pachinko': 1,
#   'palazzi': 1,
#   'palazzo': 1,
#   'pamphlet': 1,
#   'paot': 2,
#   'par': 3,
#   'paredon': 1,
#   'pas': 4,
#   'paso': 1,
#   'pater': 1,
#   "patronne's": 1,
#   'pax-ordo': 3,
#   'paxam': 1,
#   'peccavi': 1,
#   'persona': 1,
#   'personnel': 1,
#   'petits': 1,
#   'piece': 1,
#   'pokeneu': 1,
#   'polis': 1,
#   'portant': 1,
#   'post': 1,
#   'pour': 1,
#   'pratakku': 1,
#   'prie-dieu': 1,
#   'program': 1,
#   'pruta': 1,
#   'putains': 1,
#   'qua': 1,
#   'que': 1,
#   'quibusdam': 1,
#   'quo': 9,
#   'quok': 1,
#   'rasa': 2,
#   'rata': 2,
#   'realismo': 1,
#   'recit': 1,
#   'regi': 1,
#   'reipublicae': 1,
#   'resistance': 1,
#   'rouge': 1,
#   'route': 3,
#   "s'accuse": 1,
#   "s'excuse": 1,
#   'sacrificium': 2,
#   'sake': 4,
#   'sana': 1,
#   'sang': 1,
#   'sangiovanni': 1,
#   'sanitaire': 1,
#   'say': 1,
#   'sayonara': 1,
#   'scale': 1,
#   'scrutin': 2,
#   'se': 7,
#   'secco': 2,
#   'semper': 1,
#   'senioritatis': 2,
#   'seq.': 1,
#   'sic': 1,
#   'sieben': 1,
#   'sigue': 1,
#   'silvas': 1,
#   'simpliciter': 1,
#   'sind': 1,
#   'sine': 2,
#   'sinkt': 1,
#   'sit': 1,
#   'situ': 1,
#   'sou': 1,
#   'specie': 1,
#   'statu': 1,
#   'sterios': 1,
#   'strafe': 2,
#   'subpoena': 1,
#   'suite': 1,
#   'sunt': 1,
#   'superieure': 1,
#   'sur': 1,
#   'sushi': 1,
#   'sweathruna': 1,
#   'sympathique': 1,
#   'tabula': 2,
#   'tangere': 1,
#   'tecum': 1,
#   'tempeh': 1,
#   'terra': 1,
#   'terrible': 1,
#   'territoire': 1,
#   'that': 1,
#   'the': 3,
#   'thickness': 1,
#   'threefold': 1,
#   'tiefes': 1,
#   'titre': 2,
#   'to': 2,
#   'tofu': 1,
#   'tour': 1,
#   'tout': 1,
#   'traditionnel': 1,
#   'troika': 1,
#   'tultul': 3,
#   'twofold': 1,
#   'tyrannis': 1,
#   'udon': 1,
#   'um': 1,
#   'un': 1,
#   'unagi': 1,
#   'und': 2,
#   'une': 2,
#   'vade': 2,
#   'valeur': 1,
#   'vermeil': 1,
#   'verstrichen': 1,
#   'vielleicht': 1,
#   'virtuosi': 1,
#   'viva': 1,
#   'voce': 1,
#   'volens': 1,
#   'vopos': 1,
#   'vos': 1,
#   'voulez': 1,
#   'vous': 1,
#   'voyage': 1,
#   'voyageurs': 3,
#   'vrai': 1,
#   'vue': 5,
#   'wei': 2,
#   'whaddya': 1,
#   'what-will-T.': 1,
#   'which': 1,
#   'whom': 1,
#   'wiederum': 1,
#   'wohaw': 2,
#   'year': 2,
#   'years': 1,
#   'yori': 1,
#   'zorrillas': 1,
#   'zur': 1}}

# %%
i = 0
for t,v in word_counts.items():
    print(v)
    print("--------------------------------------------------------------------------------")
    i+=1
    if i >5: break
# Out:
# {'decks': 5, 'willingness': 9, 'fine': 6, 'firmness': 3, 'eggs': 26, 'Albanians': 2, 'AAA': 1, 'Davenport': 2, 'mummies': 1, 'pit': 10, 'self-satisfaction': 3, "Cibula's": 1, 'illusion': 28, 'commencement': 3, 'gourmet': 1, 'Packard': 10, 'mezzo': 1, 'madmen': 3, 'un': 1, 'Organification': 1, 'Poems': 5, 'telephone': 51, 'psychiatrist': 4, 'Siberia': 5, 'Doris': 5, 'Sagami': 1, 'B-52s': 1, 'no.': 7, 'Sea-road': 1, 'Remy': 1, 'credits': 4, 'yarns': 4, '$20,000,000': 1, 'Grenier': 2, 'exacerbation': 3, 'howls': 1, '$8,250': 1, "Berger's": 4, 'Celie': 1, 'Rumor': 4, 'boards': 34, 'Micawber': 1, 'Fruit': 3, 'Lander': 1, 'crickets': 2, 'washbasin': 1, 'Schoolmarm': 1, 'sinner': 3, 'Atlantica': 1, 'retainers': 1, 'underclassman': 1, 'equal': 1, 'firearms': 3, 'neo-dadaist': 1, '$0.9': 1, 'Conant': 5, 'ministrations': 2, 'Lilian': 6, 'Cox': 3, 'Owen': 21, 'cigarette': 18, '$2,000': 3, 'pads': 4, '$3,500,000': 2, 'pupil': 18, 'creations': 2, "Marcel's": 1, 'Sponsor': 5, 'sequence': 29, 'Plainfield': 2, 'Sangallo': 1, 'Railway': 2, 'Cahill': 1, 'modernism': 1, "Round's": 1, 'intensities': 3, 'battery': 13, "McSorley's": 1, 'Mephistopheles': 1, 'entertainers': 3, 'countenance': 6, 'Pipgras': 1, 'standby': 2, 'cluck': 1, "Berlin's": 4, 'Boeing': 3, 'innocents': 1, 'Crowds': 2, 'outpatient': 1, 'deadlines': 1, 'Mobilization': 2, 'free-world': 1, 'residue': 7, 'skins': 5, 'openings': 6, 'Strikes': 2, 'peptide': 1, 'Brownlow': 1, 'pair': 38, 'Emilio': 1, 'cornmeal': 1, 'bellboys': 1, "1/2''": 6, 'Philosophies': 1, 'Sullivan': 6, 'endogamy': 2, 'survivalist': 1, 'Orinoco': 1, 'Fujimoto': 2, "Bancroft's": 1, 'Kool-Aid': 1, 'Mack': 1, 'Insinuations': 1, 'jig': 5, 'Huddle': 1, 'Sigmund': 1, 'shell-psychology': 1, 'rat': 6, 'Pezza': 3, 'instillation': 1, 'Selena': 4, 'Artkino': 1, 'persistence': 7, 'Angelina': 4, 'escapist': 1, 'Aspencade': 1, 'embassies': 5, 'Astarte': 1, 'Long-term': 1, 'Andy': 27, 'substitution': 2, '463-degrees-C': 1, 'figures': 69, 'headboard': 1, 'Venn': 1, 'Karamazov': 3, 'Cook': 18, 'phosphors': 1, 'aviator': 3, 'Cherokee': 1, 'greenhouses': 1, 'Pi': 2, 'Basketball': 1, 'Vienot': 1, 'taxis': 2, 'weeks': 111, 'coroner': 4, 'bayleefe': 1, 'Budweisers': 1, 'comma': 1, 'credo': 7, 'jumps': 1, 'gavottes': 1, 'avail': 1, 'Rostagnos': 1, 'improvisations': 2, 'athletes': 5, 'wilderness': 8, 'incorporation': 3, 'tabloids': 1, 'Nashville': 7, 't-tau': 1, 'Fitch': 1, 'paragon': 1, 'Poitrine': 3, 'tellers': 2, 'interlining': 1, 'Alabama': 18, 'inventories': 9, 'tsunami': 17, 'elder': 1, 'ears': 27, 'Jersey': 19, 'tutorials': 1, 'polyisocyanates': 1, 'Kittler': 1, 'fairs': 1, 'mischief': 5, 'peacock': 2, 'contrast': 57, 'ignoramus': 2, 'resins': 2, 'brachii': 1, 'Gar-Dene': 2, 'author': 31, 'Jokes': 1, 'Playboy-Show-Biz': 1, 'touchdowns': 1, 'choreography': 3, 'absorbency': 1, 'horde': 2, 'Interest': 5, 'Decay': 1, 'imperfections': 2, 'happening': 2, 'Holmes': 30, 'Beiderbecke': 1, 'Meditations': 2, 'Scene': 4, 'self-crimination': 1, 'rhythms': 8, 'Fate': 3, 'chocolate': 7, '$500': 10, 'Prattville': 1, 'Amendments': 3, 'goals': 24, 'Bourbons': 3, 'Infantry': 3, 'Temper': 1, 'textiles': 9, 'slum': 6, 'tar': 2, 'Prejudice': 1, 'sinners': 2, 'Hump': 2, 'rivalry': 6, 'epoxy': 2, 'Carolina': 20, 'panel': 22, 'cruises': 1, 'Bank': 23, 'grudge': 5, 'lemon': 9, 'Maser': 1, 'impact': 50, 'Ry.': 1, 'confusions': 2, 'paratroopers': 1, 'tree-clumps': 2, 'Zinman': 1, 'Soviets': 9, 'Hartman': 3, 'Hardshell': 1, 'dealer': 19, '21%': 1, 'agnomen': 1, 'volcanos': 1, 'Anything': 13, 'Doubts': 1, 'halt': 3, 'achievements': 17, 'hoofs': 5, 'anything': 215, 'T': 60, 'exuberance': 1, 'affectation': 1, "war's": 1, 'savagery': 1, "Chicago's": 7, 'nobility': 3, 'deficiencies': 10, 'Sherlock': 4, 'Medea': 1, 'Estimate': 3, 'Louisville': 5, "Braves'": 1, 'pseudo-willing': 1, 'gullies': 1, "Dwyer's": 1, 'prodigy': 3, 'Morse': 24, '$300': 6, 'slug': 7, 'smokehouse': 2, 'vividness': 1, 'secretary-treasurer': 2, "N.C.'s": 1, 'baseballs': 1, 'Clements': 3, 'Tire':  ...
# --------------------------------------------------------------------------------
# {'infamous': 2, 'newly-emerging': 1, 'fine': 112, 'roughshod': 1, 'compensatory': 3, 'deadly': 14, 'Cooperative': 2, 'oleophobic': 1, 'scoreless': 1, 'open-collared': 1, 'all-pervading': 1, 'hemispherical': 1, 'trade-preparatory': 1, 'vaster': 1, 'unuttered': 1, 'lower-middle': 3, 'slow-moving': 1, 'monic': 3, 'congratulatory': 1, 'ikey-kikey': 1, 'foot-high': 1, 'former': 108, 'venerable': 4, 'month-long': 1, 'fine-chiseled': 1, 'tensional': 1, 'Ripe': 2, '25th': 2, 'Polytechnic': 1, 'Minor': 5, 'self-deluded': 1, 'fragmentary': 6, 'Analytical': 5, 'staggering': 3, 'misshapen': 1, 'indestructible': 1, 'alkaline': 2, 'autobiographical': 3, 'three-man': 2, 'psychoanalytic': 5, 'heartbreaking': 1, 'pragmatic': 3, 'jovial': 1, 'mid-Victorian': 1, 'unpatriotic': 1, 'equal': 63, 'Distributive': 1, 'seventeenth': 7, 'purple-black': 1, 'complaisant': 1, 'retail': 7, 'puzzling': 7, 'thirtieth': 1, 'fancier': 1, 'non-violent': 8, 'jocular': 4, 'wall-stabilized': 1, 'contemptuous': 5, 'pivotal': 1, 'prone': 10, 'inappropriate': 3, 'precautionary': 2, 'unsold': 2, 'half-crazy': 1, 'Jewish': 59, 'regulatory': 2, 'uniformed': 5, 'metropolitan': 18, '4th': 5, 'flimsy': 2, 'shoulder-high': 1, 'roundabout': 1, 'logistic': 2, 'Joint': 7, 'self-appointed': 3, 'new-found': 3, 'travelogue-like': 1, 'onetime': 1, 'naval': 16, 'fiber-coupled': 4, 'talismanic': 1, 'unwarranted': 3, 'glamorous': 4, 'bottom-living': 1, 'compact': 7, 'care-free': 1, 'unheard-of': 1, 'penultimate': 1, 'co-operative': 4, 'taut-nerved': 1, 'epigenetic': 1, 'brushy': 2, 'S.': 2, 'first-rate': 3, 'medico-military': 3, 'Linguistic': 1, 'eternal': 18, 'nine-chambered': 1, 'sharp-limbed': 1, 'delphic': 1, 'papal': 5, '139-foot': 1, 'senior-graduate': 1, 'mid-twentieth': 3, 'Gentile-Jewish': 4, 'impervious': 1, 'concrete': 15, 'egg-sized': 1, 'conversational': 2, 'military': 144, 'cranelike': 1, 'ungracious': 1, 'flashy': 3, 'frank': 16, 'retrogressive': 1, 'naked': 22, 'non-supervisory': 3, 'new-rich': 1, 'irksome': 1, 'dilute': 1, 'wan': 2, 'stringy': 2, 'Englishy': 1, 'barbed': 1, 'mesenteric': 1, 'multivalent': 1, 'unyielding': 1, '16-year-old': 1, 'acceptable': 15, 'heartfelt': 1, 'university-trained': 1, 'Holy': 28, 'monophonic': 1, 'pretentious': 6, '16-mesh': 1, 'kinder': 1, 'eligible': 12, 'acidulous': 1, 'native': 31, 'long-stemmed': 1, 'Martian': 5, 'lovelorn': 1, 'bleacher-type': 1, 'divisible': 1, 'flamboyant': 2, 'numerous': 38, 'heliocentric': 1, 'rainbow-hued': 1, 'rankest': 1, 'elder': 7, 'neural': 3, 'three-round': 1, 'seven-hit': 1, 'waist-length': 1, 'declamatory': 1, 'brotherly': 2, 'nominal': 8, 'symptomatic': 5, 'celiac': 1, 'Electoral': 1, 'societal': 2, 'electronic': 57, 'hundred-and-eighty-degree': 1, 'unceasing': 1, 'nation-building': 1, 'Handmade': 1, 'quadripartite': 1, 'jazzy': 1, 'epic': 3, 'jocund': 1, 'world-famous': 3, 'amber': 2, 'mediumistic': 1, 'uneven': 4, 'peridontal': 1, 'guttural': 2, 'four-letter': 2, 'nearer': 4, 'yellow-green': 3, 'privileged': 10, 'blood-filled': 1, 'cortical': 3, 'war-ridden': 2, 'parklike': 1, 'memorable': 9, 'Chemical': 2, 'slender-waisted': 1, 'unprofessional': 1, '23d': 5, 'nonpartisan': 1, 'state-sponsored': 1, 'German-language': 1, 'cutest': 1, 'stressful': 1, 'bullish': 1, 'Nutritious': 1, 'Future': 7, 'unreasonable': 3, 'organizational': 5, 'hable': 1, 'bashful': 1, 'Supreme': 22, 'leathery': 1, 'Famed': 1, 'supercilious': 1, 'morphologic': 1, 'nonlinguistic': 2, 'nicer': 1, 'zodiacal': 2, 'Alone': 1, '51st': 1, 'Magnetic': 1, 'bear-like': 1, 'blue-green': 3, 'hysterical': 10, 'consistent': 20, 'infirm': 1, 'traditional': 57, 'self-conscious': 5, 'poly-unsaturated': 1, 'Iron': 1, 'far': 29, 'celestial': 3, '25-year-old': 1, 'Doric': 3, 'less-hurried': 1, 'Unsuccessful': 1, 'slavish': 1, 'spiritual': 52, 'homozygous': 2, 'tangential': 1, 'Middle-South': 2, 'Strange': 7, 'unnoticed': 4, 'hearty': 4, 'subject': 30, 'dependent': 27, 'aforesaid': 1, 'tuxedoed': 1, 'blackest': 1, 'disobedient': 2, 'heavily-uphols ...
# --------------------------------------------------------------------------------
# {'fine': 3, 'persistently': 3, 'temporarily': 17, 'whereby': 17, 'rigidly': 8, 'Pretty': 3, 'unconsciously': 7, 'plenty': 5, 'thereby': 28, 'ridiculously': 2, 'Highly': 1, 'encouragingly': 1, 'paternally': 1, 'superficially': 3, 'equally': 51, 'eastward': 3, 'primly': 1, 'inadequately': 2, 'P.M.': 6, 'Vastly': 1, 'dearly': 3, 'doubtless': 9, 'Long': 2, 'upon': 28, 'more': 968, 'smilingly': 1, 'Biblically': 1, 'beautifully': 11, 'hardest': 1, 'any': 12, 'healthily': 1, 'thence': 5, 'anyways': 1, 'forcibly': 2, 'openly': 30, 'restively': 1, 'judiciously': 1, 'systematically': 8, 'bleakly': 2, 'specifically': 29, 'responsively': 1, 'Paradoxically': 3, 'admiringly': 1, 'partially': 18, 'altruistically': 1, 'overwhelmingly': 7, 'rightly': 4, 'mournfully': 1, 'cohesively': 1, 'clearly': 92, 'occasionally': 30, 'predominately': 1, 'Nearly': 5, 'yet': 173, 'ashore': 6, 'Nearby': 1, 'Typically': 3, 'admittedly': 2, 'Compassionately': 1, 'gravely': 6, 'energetically': 2, 'lastly': 1, 'Strangely': 1, 'totally': 19, 'classically': 2, 'understandably': 3, 'tactually': 1, 'So': 140, 'Indeed': 33, 'studiously': 1, 'genuinely': 8, 'yearly': 4, 'prone': 3, 'sharply': 25, 'grudgingly': 6, 'fastest': 1, 'specially': 6, 'pungently': 1, 'right': 156, 'half-heartedly': 1, 'absurdly': 1, 'orally': 1, 'attentively': 1, 'aimlessly': 1, 'recently': 88, 'harder': 14, 'warmly': 7, 'hastily': 11, 'elaborately': 6, 'sure': 14, 'geometrically': 1, 'generously': 7, 'upstairs': 19, 'nakedly': 1, 'starkly': 1, 'Properly': 1, 'about': 422, 'scientifically': 4, 'chronically': 1, 'in-state': 1, 'Mathematically': 1, 'hyperbolically': 1, 'Commonly': 1, 'faster': 12, 'how': 482, 'where': 677, 'unobtrusively': 1, 'crucially': 1, 'heatedly': 1, 'Half': 2, 'under': 9, 'invisibly': 2, 'Due': 1, 'visually': 3, 'prayerfully': 1, 'wrongly': 1, 'soaking': 3, 'mutually': 9, 'stupidly': 2, 'overboard': 8, 'best': 43, 'Significantly': 3, 'closely': 53, 'incidentally': 4, 'dynamically': 1, 'incredibly': 6, 'protectively': 1, 'diagonally': 3, 'efficaciously': 2, 'authoritatively': 1, 'comparatively': 9, 'Possibly': 3, 'eerily': 2, 'sedately': 2, 'point-blank': 1, 'Yet': 51, 'alongside': 3, 'nicely': 8, 'Mainly': 2, 'especially': 116, 'impossibly': 1, 'mortally': 1, 'rectlinearly': 1, 'More': 15, 'curiously': 7, 'advisedly': 1, 'woefully': 1, 'tartly': 1, 'hilariously': 1, 'profusely': 3, 'austerely': 1, 'Microscopically': 3, 'frankly': 9, 'independently': 10, 'absently': 4, 'already': 215, 'consequently': 12, 'piecewise': 1, 'qualitatively': 1, 'inconspicuously': 1, 'alternately': 6, 'mercifully': 2, 'brightest': 1, 'snugly': 2, 'overseas': 8, 'internationally': 3, 'Well': 21, 'listlessly': 1, 'rotationally': 1, 'Less': 5, 'crudely': 2, 'dispassionately': 1, 'narrowly': 6, 'Merely': 2, 'prickly': 1, 'directionally': 1, 'eclectically': 1, 'Jist': 2, 'prettily': 2, 'unwisely': 2, 'unselfishly': 1, 'Damn': 1, 'extra': 2, 'price-wise': 1, 'rationally': 2, 'only': 1032, 'sooner': 10, 'wolfishly': 1, 'Dimly': 1, 'Thoroughly': 1, 'grammatically': 1, 'huskily': 1, 'electrically': 1, 'expectedly': 1, 'innocently': 2, 'wordlessly': 1, 'Maybe': 55, 'Rather': 9, 'relentlessly': 3, 'inversely': 4, 'nearer': 7, 'Clearly': 7, 'onwards': 1, 'confidently': 1, 'Frequently': 6, 'except': 6, 'suddenly': 111, 'First': 33, 'piously': 1, 'Admirably': 1, 'casually': 10, 'instrumentally': 3, 'full-time': 1, 'between': 1, 'no-o': 1, 'arbitrarily': 4, 'fairly': 47, 'approvingly': 1, 'unreasonably': 1, 'Unfortunately': 14, 'a-la-Aristotle': 1, 'empirically': 4, 'internally': 3, 'nearly': 103, 'Mostly': 5, 'derisively': 1, 'Essentially': 3, 'Finally': 44, 'bitterly': 12, 'largely': 57, 'better': 129, 'strangely': 3, 'musically': 1, 'painlessly': 1, 'Alone': 2, 'thither': 1, 'overly': 7, 'here': 479, 'fearfully': 3, 'downwind': 1, 'However': 135, 'uselessly': 1, 'Feverishly': 1, 'improbably': 1, 'organizationally': 1, 'noticeably': 2, 'Largely': 1, 'lazily': 1, 'Unanimously': 1, 'far': 298, 'algebraically':  ...
# --------------------------------------------------------------------------------
# {'faires': 1, 'being': 1, 'Fermate': 1, 'mea': 1, 'an': 1, 'a': 5, 'rouge': 1, 'Carrozza': 1, 'Chambre': 1, 'deux': 3, 'Ecole': 1, 'more': 1, 'en': 3, 'persona': 1, 'and': 2, 'Wanderjahr': 1, 'je': 1, 'Hexen': 1, 'Femmes': 1, 'monde': 1, 'bona': 1, 'faim': 1, 'noir': 1, 'the': 3, 'LD': 1, 'subpoena': 1, 'Douce': 1, 'pax-ordo': 3, 'habe': 1, '32-degrees-C': 1, 'illusions': 1, 'sind': 1, 'Prix': 1, 'zorrillas': 1, 'engages': 4, 'obliterans': 1, 'la': 7, 'Vergessen': 1, 'Arigato': 1, 'comedie': 1, 'me': 1, 'alors': 1, 'electriques': 1, 'Sur': 2, 'Jardin': 1, 'Sinfonica': 1, 'Grand': 1, 'enfant': 1, 'age': 1, 'un': 1, 'vopos': 1, 'Alsatian': 1, 'reipublicae': 1, 'Grands': 3, 'ne': 1, 'be': 2, '32*0C.': 1, 'Buenas': 1, 'Tour': 2, 'about': 1, 'titre': 2, 'Strukturbericht': 1, 'valeur': 1, 'ASPIS': 1, 'Recherche': 1, 'Philharmonique': 1, 'adieu': 1, 'Serieuses': 1, 'S.': 1, 'morgen': 1, 'Klinico': 1, 'Rundfunk': 1, 'basso': 1, 'Artisans': 1, 'basileis': 1, 'continuo': 1, 'Pati': 1, 'that': 1, "L'Arcade": 1, 'situ': 1, 'que': 1, 'Zeitgeist': 1, 'Arte': 4, 'superieure': 1, 'Conquete': 1, 'scrutin': 2, 'vermeil': 1, 'etes': 1, 'Afrique': 1, 'fide': 1, 'Statuto': 1, 'Gott': 1, 'metis': 1, 'Della': 2, 'le': 3, "s'accuse": 1, 'sang': 1, 'khaneh': 1, 'Sole': 1, 'Son': 1, 'Amt': 1, '43*0C': 1, 'Dummkopf': 1, 'miuchi': 1, 'Pro': 1, 'voyage': 1, 'sigue': 1, 'des': 2, 'sacrificium': 2, 'Die': 4, 'Kristallstrukturen': 1, 'yori': 1, 'boites': 1, 'sieben': 1, 'fille': 5, "d'art": 1, 'Servanda': 1, 'banditos': 1, "l'Independance": 1, 'oui': 1, 'bouffe': 1, 'thickness': 1, 'given': 1, 'El': 2, 'Tory': 1, 'sanitaire': 1, 'Telegraphie': 1, 'Then': 1, 'Concertante': 1, 'Scientifique': 1, 'may': 1, '(': 9, 'tangere': 1, "J'ai": 1, 'apartheid': 1, 'petits': 1, 'volens': 1, 'years': 1, 'Ciao': 1, 'rasa': 2, 'Fil': 1, 'Homo': 1, 'bratwurst': 1, 'pater': 1, 'noire': 1, 'sympathique': 1, 'kolkhozes': 2, 'vade': 2, 'chimiques': 1, 'pokeneu': 1, 'Arc': 1, 'conquete': 1, 'Stadtisches': 1, 'und': 2, 'aquam': 1, 'putains': 1, 'negociants': 1, 'Quod': 1, 'Crus': 3, 'filles': 1, 'garde': 1, "ksu'u'peli'afo": 1, 'Romanza': 1, 'das': 1, 'culte': 1, 'palazzo': 1, 'Qui': 1, 'Samba': 1, 'difficile': 1, 'Democratique': 1, 'Sans': 1, 'cocu': 1, 'Toujours': 1, 'Les': 1, 'et': 21, 'attack': 1, 'chole': 1, 'attis': 1, 'Missa': 1, 'milord': 2, 'Deus': 1, 'Rapport': 1, 'avec': 1, 'Mi': 1, 'chantier': 1, 'sunt': 1, 'frise': 1, 'whom': 1, 'Rue': 3, 'secco': 2, 'Naturam': 1, "d'un": 1, 'pas': 4, 'oyabun': 4, 'Krystallographie': 3, 'Liber': 1, 'coup': 1, 'resistance': 1, 'sangiovanni': 1, 'Musique': 1, 'C.': 1, 'circonscriptions': 1, 'as': 1, 'he': 2, 'eine': 1, 'Solemnis': 1, 'Weltanschauung': 1, 'voulez': 1, 'chambre': 3, 'Calimala': 1, 'Generale': 3, 'pachinko': 1, "l'Ange": 1, 'even': 1, 'entered': 1, 'blutwurst': 1, 'heute': 1, 'firma': 1, 'Compagnie': 1, '43*0C.': 1, 'Dolce': 5, 'Affaires': 1, 'Konzerthaus': 1, 'Gladius': 1, 'Spagna': 1, 'vielleicht': 1, 'Nichtige': 1, 'lange': 1, 'tofu': 1, 'Das': 1, 'Notitia': 1, 'mater': 1, 'Lumiere': 1, 'sine': 2, 'mais': 1, 'Crisis': 1, 'Officielle': 1, 'Medecine': 1, 'paso': 1, 'maria': 1, 'Reine': 1, 'sur': 1, 'Whaddya': 1, '135*0C.': 1, 'Pater': 1, 'Dunkirk': 1, "s'excuse": 1, "L'Union": 2, 'Bayerische': 1, 'Pueri': 1, 'Y': 1, 'vue': 5, '-': 5, 'or': 1, 'Einsatzkommandos': 1, 'con': 3, 'Angleterre': 1, 'Vita': 5, 'Curiae': 1, "l'identite": 1, 'Belge': 1, 'bois': 1, 'Karshilama': 1, 'cetera': 4, 'semper': 1, 'Eliot-or-Martin': 1, 'construction': 1, 'unagi': 1, 'portant': 1, 'ordo': 3, 'cordon': 1, 'um': 1, 'exceed': 1, 'forisque': 1, 'kwashiorkor': 1, "d'etat": 1, 'bete': 1, 'infinitum': 1, 'ersatz': 2, 'Nuit': 2, 'Allons': 1, 'demographiques': 1, 'commence': 1, 'Planeten': 1, 'program': 1, 'can': 1, 'Orchester': 1, 'Demographie': 1, 'seq.': 1, 'suite': 1, 'tecum': 1, 'if': 1, 'novo': 1, 'auf': 1, 'senioritatis': 2, 'Bon': 2, 'Orchestre': 1, 'Chili': 1, 'Tanin': 1, "d'hotel": 1, 'Centrale': 1, 'ein': 2, 'del': 1, 'Redoute': 3, 'Grammo ...
# --------------------------------------------------------------------------------
# {'choose': 34, 'thawing': 2, 'fine': 1, 'motioned': 1, 'overcast': 1, 'appeasing': 1, 'Noting': 5, 'pit': 1, 'concedes': 1, 'whipsawed': 1, 'practising': 1, 'pupates': 1, 'amaze': 2, 'Stroked': 1, 'evoking': 1, 'accustomed': 14, 'snowing': 3, 'wiggled': 1, 'glinted': 1, 'Skip': 1, 'telephone': 2, 'define': 16, 'subtended': 1, 'trouble': 4, 'formulated': 10, 'charm': 2, 'take': 463, 'honeymoon': 1, 'smiled': 57, 'ripening': 2, 'Setting': 1, 'sang': 21, 'reclining': 2, 'overreached': 2, 'rent': 13, 'precut': 1, 'refreshing': 1, 'overthrow': 2, 'Insulate': 1, 'spike': 1, 'woolgather': 1, 'demolished': 4, 'winking': 5, 'armored': 3, 'running': 95, 'boards': 1, 'reproduce': 6, 'reveling': 1, 'Plank': 1, 'delineated': 1, 'annunciated': 1, 'sprawling': 5, 'Coaching': 2, 'refuted': 3, 'chop': 1, 'chide': 2, 'perishing': 1, 'wear': 25, 'rises': 16, 'combatted': 1, 'equal': 6, 'reminding': 2, 'Cap': 2, 'brok': 1, 'toss': 4, 'overcoming': 5, 'Dazed': 1, 'quilted': 1, 'Caring': 1, 'cheered': 2, 'rating': 3, 'sticle': 1, 'counted': 16, 'maximizing': 3, 'wooed': 1, 'doped': 1, 'prejudged': 1, 'opening': 45, 'contains': 26, 'proselytizing': 1, 'enrolled': 6, 'charted': 4, 'motioning': 1, 'agree': 36, 'finds': 46, 'musta': 1, 'confuse': 5, 'identifying': 3, 'chicken': 1, 'beckoning': 1, 'obscured': 5, 'supplanted': 1, 'Inspiring': 2, 'rooted': 5, 'taped': 1, 'panting': 8, 'lingered': 2, 'tracking': 1, 'dangle': 1, 'integrated': 10, 'codetermines': 1, 'revelling': 1, 're-establishing': 1, 'fertilized': 2, 'bubbles': 1, 'bribed': 2, 'reach': 78, 'tumbled': 9, 'proclaim': 10, 'drooped': 1, 'venerated': 2, 'terminating': 1, 'quickened': 1, 'interfere': 9, 'chase': 3, 'shivered': 4, 'skins': 1, 'dash': 1, 'reassemble': 2, 'argue': 23, 'compile': 1, 'longing': 4, 'pilot': 2, 'compels': 2, 'interlocking': 6, 'beats': 2, 'labelled': 1, 'hustle': 1, 'settling': 8, 'Drifts': 1, 'peeping': 1, 'contenting': 1, 'zipped': 1, 'reread': 2, 'illustrating': 4, 'breathing': 12, 'flowering': 1, 'seasoned': 5, 'garaged': 1, 'Armed': 20, 'abstract': 3, 'radio': 1, 'cooking': 23, 'wedded': 3, 'portraying': 2, 'superimposes': 1, 'looped': 1, 'Denouncing': 1, 'watered': 7, 'jammed': 7, 'soaking': 5, 'wangled': 1, 'wrenching': 1, 'Dropping': 1, 'collects': 5, 'dominated': 17, 'enthralled': 1, 'recognizes': 9, 'synthesizes': 1, 'amuse': 2, 'emigrating': 1, 'yelled': 19, 'paired': 5, 'strayed': 1, 'marketed': 2, 'fermented': 3, 'tilted': 9, 'adsorbs': 1, 'quarreled': 4, 'bullying': 1, 'returning': 26, 'spell': 3, 'arrested': 18, 'cracks': 1, 'doo': 2, 'stewed': 1, 'tapping': 2, 'Selecting': 2, 'figures': 2, 'stroking': 1, 'ground': 14, 'alludes': 1, 'dazzles': 1, 'Study': 4, 'treats': 9, 'Related': 3, 'recommends': 2, 'reek': 1, 'respecting': 3, 'educate': 5, 'barbed': 6, 'Form': 1, 'Walk': 2, 'Hail': 5, 'barred': 6, 'escapes': 2, 'Sharing': 1, 'suffused': 5, 'strapping': 2, 'tarred': 1, 'aerate': 1, 'stride': 4, 'imbedded': 3, 'programing': 7, 'half-reached': 1, 'avail': 2, 'clotted': 1, 'scribbled': 1, 'discharge': 3, 'prohibit': 1, 'surrounding': 20, 'dismembered': 1, 'retreated': 8, 'spurring': 1, 'amend': 2, 'meet': 107, 'signaled': 2, 'Reaching': 3, 'Ground': 1, 'derived': 29, 'totaled': 5, 'alight': 1, 'cruising': 5, 'massaging': 1, 'twirling': 5, 'stressing': 4, 'Budgeting': 1, 'assess': 6, 'hammered': 3, 'overshadowed': 1, 'kin': 1, 'broach': 1, 'harm': 1, 'heaved': 4, 'accumulate': 2, 'worn': 14, 'adore': 2, 'toll': 1, 'contrast': 3, 'stated': 58, 'enabled': 11, 'groaned': 3, 'asked': 296, 'polled': 1, 'marching': 9, 'sewed': 1, 'enhancing': 1, 'donates': 1, 'flees': 1, 'Lives': 1, 'answered': 54, 'chatting': 2, 'luring': 1, 'Lay': 1, 'Finished': 1, 'burrow': 1, 'astonished': 6, 'exchanged': 5, 'receding': 4, 'happening': 25, 'separating': 5, 'stifled': 1, 'dreaded': 1, 'affecting': 5, 'twittering': 1, 'inserted': 12, 'forcing': 10, 'concerns': 12, 'stave': 1, 'insulated': 2, 'meets': 24, 'stains': 1, 'Happened': 3, 'Buries': 1, 'experimenting': 6, 'analysed': ...
# --------------------------------------------------------------------------------
# {'but': 2301, 'or': 3218, 'nor': 127, 'and': 22369, '&': 138, 'minus': 2, 'And': 770, 'Yet': 57, 'Neither': 18, "'n'": 2, 'an': 10, 'either': 135, 'Plus': 1, "An'": 1, 'butt': 2, 'But': 1105, 'Nor': 28, 'neither': 66, 'yet': 45, "an'": 5, 'Or': 72, 'and/or': 14, 'plus': 44, 'An': 1, 'Either': 6}
# --------------------------------------------------------------------------------

# %%
mfc_table = # TODO: YOUR CODE HERE

# DO NOT MODIFY BELOW THIS LINE
mfc_model = MFCTagger(mfc_table) # Create a Most Frequent Class tagger instance

# %%
assert len(mfc_table) == len(data.training_set.vocab), ""
assert all(k in data.training_set.vocab for k in mfc_table.keys()), ""
assert sum(int(k not in mfc_table) for k in data.testing_set.vocab) == 5521, ""
HTML('<div class="alert alert-block alert-success">Your MFC tagger has all the correct words!</div>')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-23-40aaaf0ca4ed> in <module>()
# ----> 1 assert len(mfc_table) == len(data.training_set.vocab), ""
#       2 assert all(k in data.training_set.vocab for k in mfc_table.keys()), ""
#       3 assert sum(int(k not in mfc_table) for k in data.testing_set.vocab) == 5521, ""
#       4 HTML('<div class="alert alert-block alert-success">Your MFC tagger has all the correct words!</div>')
#
# AssertionError:

# %% [markdown]
# ### Making Predictions with a Model
# The helper functions provided below interface with Pomegranate network models & the mocked MFCTagger to take advantage of the [missing value](http://pomegranate.readthedocs.io/en/latest/nan.html) functionality in Pomegranate through a simple sequence decoding function. Run these functions, then run the next cell to see some of the predictions made by the MFC tagger.

# %%
def replace_unknown(sequence):
    """Return a copy of the input sequence where each unknown word is replaced
    by the literal string value 'nan'. Pomegranate will ignore these values
    during computation.
    """
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):
    """X should be a 1-D sequence of observations for the model to predict"""
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]  # do not show the start/end state predictions

# %% [markdown]
# ### Example Decoding Sequences with MFC Tagger

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")

# %% [markdown]
# ### Evaluating Model Accuracy
#
# The function below will evaluate the accuracy of the MFC tagger on the collection of all sentences from a text corpus.

# %%
def accuracy(X, Y, model):
    """Calculate the prediction accuracy by using the model to decode each sequence
    in the input X and comparing the prediction with the true labels in Y.
    
    The X should be an array whose first dimension is the number of sentences to test,
    and each element of the array should be an iterable of the words in the sequence.
    The arrays X and Y should have the exact same shape.
    
    X = [("See", "Spot", "run"), ("Run", "Spot", "run", "fast"), ...]
    Y = [(), (), ...]
    """
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %% [markdown]
# #### Evaluate the accuracy of the MFC tagger
# Run the next cell to evaluate the accuracy of the tagger on the training and test corpus.

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))

assert mfc_training_acc >= 0.955, "Uh oh. Your MFC accuracy on the training set doesn't look right."
assert mfc_testing_acc >= 0.925, "Uh oh. Your MFC accuracy on the testing set doesn't look right."
HTML('<div class="alert alert-block alert-success">Your MFC tagger accuracy looks correct!</div>')

# %% [markdown]
# ## Step 3: Build an HMM tagger
# ---
# The HMM tagger has one hidden state for each possible tag, and parameterized by two distributions: the emission probabilties giving the conditional probability of observing a given **word** from each hidden state, and the transition probabilities giving the conditional probability of moving between **tags** during the sequence.
#
# We will also estimate the starting probability distribution (the probability of each **tag** being the first tag in a sequence), and the terminal probability distribution (the probability of each **tag** being the last tag in a sequence).
#
# The maximum likelihood estimate of these distributions can be calculated from the frequency counts as described in the following sections where you'll implement functions to count the frequencies, and finally build the model. The HMM model will make predictions according to the formula:
#
# $$t_i^n = \underset{t_i^n}{\mathrm{argmax}} \prod_{i=1}^n P(w_i|t_i) P(t_i|t_{i-1})$$
#
# Refer to Speech & Language Processing [Chapter 10](https://web.stanford.edu/~jurafsky/slp3/10.pdf) for more information.

# %% [markdown]
# ### IMPLEMENTATION: Unigram Counts
#
# Complete the function below to estimate the co-occurrence frequency of each symbol over all of the input sequences. The unigram probabilities in our HMM model are estimated from the formula below, where N is the total number of samples in the input. (You only need to compute the counts for now.)
#
# $$P(tag_1) = \frac{C(tag_1)}{N}$$

# %%
def unigram_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequence list that
    counts the number of occurrences of the value in the sequences list. The sequences
    collection should be a 2-dimensional array.
    
    For example, if the tag NOUN appears 275558 times over all the input sequences,
    then you should return a dictionary such that your_unigram_counts[NOUN] == 275558.
    """
    # TODO: Finish this function!
    raise NotImplementedError

# TODO: call unigram_counts with a list of tag sequences from the training set
tag_unigrams = unigram_counts(# TODO: YOUR CODE HERE)

assert set(tag_unigrams.keys()) == data.training_set.tagset, \
       "Uh oh. It looks like your tag counts doesn't include all the tags!"
assert min(tag_unigrams, key=tag_unigrams.get) == 'X', \
       "Hmmm...'X' is expected to be the least common class"
assert max(tag_unigrams, key=tag_unigrams.get) == 'NOUN', \
       "Hmmm...'NOUN' is expected to be the most common class"
HTML('<div class="alert alert-block alert-success">Your tag unigrams look good!</div>')

# %% [markdown]
# ### IMPLEMENTATION: Bigram Counts
#
# Complete the function below to estimate the co-occurrence frequency of each pair of symbols in each of the input sequences. These counts are used in the HMM model to estimate the bigram probability of two tags from the frequency counts according to the formula: $$P(tag_2|tag_1) = \frac{C(tag_2|tag_1)}{C(tag_2)}$$

# %%
def bigram_counts(sequences):
    """Return a dictionary keyed to each unique PAIR of values in the input sequences
    list that counts the number of occurrences of pair in the sequences list. The input
    should be a 2-dimensional array.
    
    For example, if the pair of tags (NOUN, VERB) appear 61582 times, then you should
    return a dictionary such that your_bigram_counts[(NOUN, VERB)] == 61582
    """

    # TODO: Finish this function!
    raise NotImplementedError

# TODO: call bigram_counts with a list of tag sequences from the training set
tag_bigrams = bigram_counts(# TODO: YOUR CODE HERE)

assert len(tag_bigrams) == 144, \
       "Uh oh. There should be 144 pairs of bigrams (12 tags x 12 tags)"
assert min(tag_bigrams, key=tag_bigrams.get) in [('X', 'NUM'), ('PRON', 'X')], \
       "Hmmm...The least common bigram should be one of ('X', 'NUM') or ('PRON', 'X')."
assert max(tag_bigrams, key=tag_bigrams.get) in [('DET', 'NOUN')], \
       "Hmmm...('DET', 'NOUN') is expected to be the most common bigram."
HTML('<div class="alert alert-block alert-success">Your tag bigrams look good!</div>')

# %% [markdown]
# ### IMPLEMENTATION: Sequence Starting Counts
# Complete the code below to estimate the bigram probabilities of a sequence starting with each tag.

# %%
def starting_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequences list
    that counts the number of occurrences where that value is at the beginning of
    a sequence.
    
    For example, if 8093 sequences start with NOUN, then you should return a
    dictionary such that your_starting_counts[NOUN] == 8093
    """
    # TODO: Finish this function!
    raise NotImplementedError

# TODO: Calculate the count of each tag starting a sequence
tag_starts = starting_counts(# TODO: YOUR CODE HERE)

assert len(tag_starts) == 12, "Uh oh. There should be 12 tags in your dictionary."
assert min(tag_starts, key=tag_starts.get) == 'X', "Hmmm...'X' is expected to be the least common starting bigram."
assert max(tag_starts, key=tag_starts.get) == 'DET', "Hmmm...'DET' is expected to be the most common starting bigram."
HTML('<div class="alert alert-block alert-success">Your starting tag counts look good!</div>')

# %% [markdown]
# ### IMPLEMENTATION: Sequence Ending Counts
# Complete the function below to estimate the bigram probabilities of a sequence ending with each tag.

# %%
def ending_counts(sequences):
    """Return a dictionary keyed to each unique value in the input sequences list
    that counts the number of occurrences where that value is at the end of
    a sequence.
    
    For example, if 18 sequences end with DET, then you should return a
    dictionary such that your_starting_counts[DET] == 18
    """
    # TODO: Finish this function!
    raise NotImplementedError

# TODO: Calculate the count of each tag ending a sequence
tag_ends = ending_counts(# TODO: YOUR CODE HERE)

assert len(tag_ends) == 12, "Uh oh. There should be 12 tags in your dictionary."
assert min(tag_ends, key=tag_ends.get) in ['X', 'CONJ'], "Hmmm...'X' or 'CONJ' should be the least common ending bigram."
assert max(tag_ends, key=tag_ends.get) == '.', "Hmmm...'.' is expected to be the most common ending bigram."
HTML('<div class="alert alert-block alert-success">Your ending tag counts look good!</div>')

# %% [markdown]
# ### IMPLEMENTATION: Basic HMM Tagger
# Use the tag unigrams and bigrams calculated above to construct a hidden Markov tagger.
#
# - Add one state per tag
#     - The emission distribution at each state should be estimated with the formula: $P(w|t) = \frac{C(t, w)}{C(t)}$
# - Add an edge from the starting state `basic_model.start` to each tag
#     - The transition probability should be estimated with the formula: $P(t|start) = \frac{C(start, t)}{C(start)}$
# - Add an edge from each tag to the end state `basic_model.end`
#     - The transition probability should be estimated with the formula: $P(end|t) = \frac{C(t, end)}{C(t)}$
# - Add an edge between _every_ pair of tags
#     - The transition probability should be estimated with the formula: $P(t_2|t_1) = \frac{C(t_1, t_2)}{C(t_1)}$

# %%
basic_model = HiddenMarkovModel(name="base-hmm-tagger")

# TODO: create states with emission probability distributions P(word | tag) and add to the model
# (Hint: you may need to loop & create/add new states)
basic_model.add_states()

# TODO: add edges between states for the observed transition frequencies P(tag_i | tag_i-1)
# (Hint: you may need to loop & add transitions
basic_model.add_transition()


# NOTE: YOU SHOULD NOT NEED TO MODIFY ANYTHING BELOW THIS LINE
# finalize the model
basic_model.bake()

assert all(tag in set(s.name for s in basic_model.states) for tag in data.training_set.tagset), \
       "Every state in your network should use the name of the associated tag, which must be one of the training set tags."
assert basic_model.edge_count() == 168, \
       ("Your network should have an edge from the start node to each state, one edge between every " +
        "pair of tags (states), and an edge from each state to the end node.")
HTML('<div class="alert alert-block alert-success">Your HMM network topology looks good!</div>')

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, basic_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, basic_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))

assert hmm_training_acc > 0.97, "Uh oh. Your HMM accuracy on the training set doesn't look right."
assert hmm_testing_acc > 0.955, "Uh oh. Your HMM accuracy on the testing set doesn't look right."
HTML('<div class="alert alert-block alert-success">Your HMM tagger accuracy looks correct! Congratulations, you\'ve finished the project.</div>')

# %% [markdown]
# ### Example Decoding Sequences with the HMM Tagger

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, basic_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")

# %% [markdown]
# ## Finishing the project
# ---
#
# <div class="alert alert-block alert-info">
# **Note:** **SAVE YOUR NOTEBOOK**, then run the next cell to generate an HTML copy. You will zip & submit both this file and the HTML copy for review.
# </div>

# %%
# !!jupyter nbconvert *.ipynb

# %% [markdown]
# ## Step 4: [Optional] Improving model performance
# ---
# There are additional enhancements that can be incorporated into your tagger that improve performance on larger tagsets where the data sparsity problem is more significant. The data sparsity problem arises because the same amount of data split over more tags means there will be fewer samples in each tag, and there will be more missing data  tags that have zero occurrences in the data. The techniques in this section are optional.
#
# - [Laplace Smoothing](https://en.wikipedia.org/wiki/Additive_smoothing) (pseudocounts)
#     Laplace smoothing is a technique where you add a small, non-zero value to all observed counts to offset for unobserved values.
#
# - Backoff Smoothing
#     Another smoothing technique is to interpolate between n-grams for missing data. This method is more effective than Laplace smoothing at combatting the data sparsity problem. Refer to chapters 4, 9, and 10 of the [Speech & Language Processing](https://web.stanford.edu/~jurafsky/slp3/) book for more information.
#
# - Extending to Trigrams
#     HMM taggers have achieved better than 96% accuracy on this dataset with the full Penn treebank tagset using an architecture described in [this](http://www.coli.uni-saarland.de/~thorsten/publications/Brants-ANLP00.pdf) paper. Altering your HMM to achieve the same performance would require implementing deleted interpolation (described in the paper), incorporating trigram probabilities in your frequency tables, and re-implementing the Viterbi algorithm to consider three consecutive states instead of two.
#
# ### Obtain the Brown Corpus with a Larger Tagset
# Run the code below to download a copy of the brown corpus with the full NLTK tagset. You will need to research the available tagset information in the NLTK docs and determine the best way to extract the subset of NLTK tags you want to explore. If you write the following the format specified in Step 1, then you can reload the data using all of the code above for comparison.
#
# Refer to [Chapter 5](http://www.nltk.org/book/ch05.html) of the NLTK book for more information on the available tagsets.

# %%
import nltk
from nltk import pos_tag, word_tokenize
from nltk.corpus import brown

nltk.download('brown')
training_corpus = nltk.corpus.brown
training_corpus.tagged_sents()[0]
